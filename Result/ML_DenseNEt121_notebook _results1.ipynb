# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
import tqdm
import pandas as pd
import keras
import time, warnings
import tensorflow
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from keras_tuner.tuners import RandomSearch
from sklearn.model_selection import KFold, train_test_split, LeaveOneGroupOut, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, f1_score
from sklearn.metrics import confusion_matrix
import keras_tuner
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import (
    Dense,
    Conv1D,
    MaxPooling1D,
    BatchNormalization,
    Dropout,
    Flatten,
    Conv2D,
    MaxPool2D,
    Activation,
    GlobalAveragePooling2D,
)
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

warnings.filterwarnings("ignore")

# %%
#class for plotting
class PlotLearning(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.metrics = {}
        for metric in logs:
            self.metrics[metric] = []

    def on_epoch_end(self, epoch, logs={}):
        # Storing metrics
        for metric in logs:
            if metric in self.metrics:
                self.metrics[metric].append(logs.get(metric))
            else:
                self.metrics[metric] = [logs.get(metric)]

        # Plotting
        metrics = [x for x in logs if 'val' not in x]

        f, axs = plt.subplots(1, len(metrics), figsize=(15, 5))

        for i, metric in enumerate(metrics):
            axs[i].plot(range(1, epoch + 2),
                        self.metrics[metric],
                        label=metric)
            if logs['val_' + metric]:
                axs[i].plot(range(1, epoch + 2),
                            self.metrics['val_' + metric],
                            label='val_' + metric)

            axs[i].legend()
            axs[i].grid()

        plt.tight_layout()
        plt.show()

def normalize(clip):
    normalized_clip = (clip - np.min(clip)) / (np.max(clip) - np.min(clip))
    return normalized_clip

def conv_array(root_folder):
    metadata = pd.read_csv('/content/drive/MyDrive/UrbanSound8kv2/Data_extracted_3/processed_data.csv')
    folds = {}
    for fold in range(1, 11):
        fold_path = os.path.join(root_folder, f"fold{fold}")
        image_data = []
        all_labels = []
        if not os.path.exists(fold_path):
            continue  # Skip if the folder doesn't exist
        for filename in tqdm.tqdm(os.listdir(fold_path)):
            if filename.endswith(".png"):
                image_path = os.path.join(fold_path, filename)
                image = Image.open(image_path)
                new_filename = filename.replace('.png', '.wav')
                row_num = metadata[metadata['slice_file_name'] == new_filename].index
                if not row_num.empty:
                    image_array = np.array(image)
                    if not image_array.shape == (76, 33):
                      continue
                    image_array = normalize(image_array)
                    #image_array = tensorflow.image.grayscale_to_rgb(image_array)
                    #print(image_array.shape)
                    image_array = np.ndarray(shape=(image_array.shape[0], image_array.shape[1], 1), dtype= np.uint8)
                    label = metadata.iloc[row_num]['labelID'].values[0]
                    #print(f'Double check: image {new_filename} has label {label}')
                    all_labels.append(label)
                    image_data.append(image_array)
                else:
                    print(f'{new_filename} not found')
                    continue
        image_data = np.array(image_data)
        #print(image_data)
        all_labels = np.array(all_labels)
        all_labels = to_categorical(all_labels - 1, num_classes=10)
        #converting numpy arrays to tf.tensor for GPU optimization
        image_data_tensor = tensorflow.convert_to_tensor(image_data)
        all_labels_tensor = tensorflow.convert_to_tensor(all_labels)
        #print(image_data_tensor)
        image_data_tensor = tensorflow.image.grayscale_to_rgb(image_data_tensor)
        folds[f"fold{fold}"] = [image_data_tensor, all_labels_tensor]
    return folds


root_folder = r"/content/drive/MyDrive/UrbanSound8kv2/Data_extracted_3/both"
data = conv_array(root_folder)
input_shape = data['fold1'][0].shape
#input_shape = input_shape + (3,)
print(input_shape)
# Out:
# 100%|██████████| 873/873 [00:15<00:00, 55.13it/s]
# 100%|██████████| 888/888 [00:10<00:00, 82.82it/s]
# 100%|██████████| 925/925 [00:10<00:00, 84.74it/s]
# 100%|██████████| 990/990 [00:11<00:00, 83.92it/s]
# 100%|██████████| 936/936 [00:12<00:00, 74.05it/s]
# 100%|██████████| 823/823 [00:10<00:00, 75.89it/s]
# 100%|██████████| 838/838 [00:09<00:00, 91.54it/s]
# 100%|██████████| 806/806 [00:13<00:00, 61.61it/s]
# 100%|██████████| 816/816 [00:09<00:00, 88.03it/s]
# 100%|██████████| 837/837 [00:09<00:00, 87.68it/s]
# (873, 76, 33, 3)

# %%
print(input_shape)
input_shape2 = input_shape[1:4]
print(input_shape2)
# Out:
# (873, 76, 33, 3)
# (76, 33, 3)

# %%
tensorflow.keras.backend.clear_session()

metric = 'accuracy' #evaluation metric
#metric = tensorflow.keras.metrics.MeanAveragePrecisionMetric(topn=2)
loss= 'categorical_crossentropy' #loss function

#training parameters
num_epoch = 30
batch_size = 128
early_stop = 10 # early stoppping after 3 epochs with no improvement of test data
#trainable layers needs a minus infront
trainable_layers = -10
dropout_rate = 0.5
learning_rate = 0.001


def model_k_cross(data):
    list_scores = []
    #Densenet121 model using pretrained weights from imagenet
    model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=input_shape[1:4], classes=10)

    x=model_d.output
    x= GlobalAveragePooling2D()(x)
    x= BatchNormalization()(x)
    x= Dropout(dropout_rate)(x)
    x= Dense(1024,activation='relu')(x)
    x= Dense(512,activation='relu')(x)
    x= BatchNormalization()(x)
    x= Dropout(dropout_rate)(x)
    preds=Dense(10,activation='softmax')(x) #FC-layer
    model=Model(inputs=model_d.input,outputs=preds)

    #instance of Adam optimizer
    Adam = keras.optimizers.Adam(learning_rate=learning_rate)


    #To avoid the problem of overfitting, avoid training the entire network. layer.trainable=False will freeze all the layers, keeping only the last eight layers (FC) to detect edges and blobs in the image. Once the model is fitted well, it can be fine-tuned by using layer.trainable=True.
    for layer in model.layers[:trainable_layers]:
        layer.trainable=False
    for layer in model.layers[trainable_layers:]:
        layer.trainable=True

    model.summary()



    for fold_name, fold_data in tqdm.tqdm(data.items()):
        tensorflow.keras.backend.clear_session()
        print(f"Training using {fold_name} as validation")
        X_val, y_val = fold_data[0], fold_data[1]
        X_train = []
        y_train = []

        for other_fold_name, other_fold_data in data.items():
            if other_fold_name == fold_name:
                continue

            X = other_fold_data[0]
            y = other_fold_data[1]
            X_train.extend(X)
            y_train.extend(y)

        X_train = np.array(X_train)
        y_train = np.array(y_train)

        model.compile(optimizer=Adam,loss='categorical_crossentropy',metrics=['accuracy'])
        EarlyStoppingCallback = tensorflow.keras.callbacks.EarlyStopping(monitor='val_loss', patience=early_stop)


        #If the model sees no change in validation loss the ReduceLROnPlateau function will reduce the learning rate, which often benefits the model. The ImageDataGenerator function performs real-time data augmentation over generated tensor image data batches in a loop.
        anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
        checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
        datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)
        datagen.fit(X_train)

        history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=128),
                       steps_per_epoch=X_train.shape[0] //128,
                       epochs=num_epoch,
                       verbose=2,
                       callbacks=[anne, checkpoint, EarlyStoppingCallback],
                       validation_data=(X_val, y_val))

        # Evaluation
        scores = model.evaluate(X_val, y_val)
        print("Validation accuracy:", scores[1])
        list_scores.append(scores[1])


        # Plot training history - loss
        print(history.history.keys())
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title(f"Training Loss - {fold_name} as validation")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Training Loss', 'Validation Loss'], loc='upper left')
        plt.show()

        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title(f"Accuracy - {fold_name} as validation")
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Training accuracy', 'Validation accuracy'], loc='upper left')
        plt.show()


    average_acc = sum(list_scores) / len(list_scores)
    print(f'List of scores{list_scores}')
    print(f'Average accuracy: {average_acc}')
    print(f'Trained only the last {trainable_layers} layers')

    total = 0
    accurate = 0
    accurateindex = []
    wrongindex = []
    label = ['air_conditioning', 'car_horn', 'children_playing', 'dog_bark', 'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 'siren', 'street_music']

    Ypred = model.predict(X_val)

    for i in range(len(Ypred)):
        if np.argmax(Ypred[i]) == np.argmax(y_val[i]):
            accurate += 1
            accurateindex.append(i)
        else:
            wrongindex.append(i)

        total += 1

    Ypred = np.argmax(Ypred, axis=1)
    Ytrue = np.argmax(y_val, axis=1)
    cm = confusion_matrix(Ytrue, Ypred)
    plt.figure(figsize=(12, 12))
    ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
    ax.set_ylabel('Actual', fontsize=20)
    ax.set_xlabel('Predicted', fontsize=20)


    print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
    print('Accuracy:', round(accurate/total*100, 3), '%')


model_k_cross(data)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 76, 33, 3)]          0         []
#
#  zero_padding2d (ZeroPaddin  (None, 82, 39, 3)            0         ['input_1[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 38, 17, 64)           9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 38, 17, 64)           256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 38, 17, 64)           0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 40, 19, 64)           0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 19, 9, 64)            0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 19, 9, 64)            256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 19, 9, 64)            0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 19, 9, 128)           8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 19, 9, 128)           512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 19, 9, 128)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 19, 9, 32)            36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 19, 9, 96)            0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 19, 9, 96)            384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 19, 9, 96)            0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 19, 9, 128)           12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 19, 9, 128)           512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 19, 9, 128)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 19, 9, 32)            36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 19, 9, 128)           0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 19, 9, 128)           512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 19, 9, 128)           0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 19, 9, 128)           16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 19, 9, 128)           512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 19, 9, 128)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 19, 9, 32)            36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 19, 9, 160)           0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 19, 9, 160)           640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 19, 9, 160)           0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 19, 9, 128)           20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 19, 9, 128)           512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 19, 9, 128)           0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 19, 9, 32)            36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 19, 9, 192)           0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 19, 9, 192)           768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 19, 9, 192)           0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 19, 9, 128)           24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 19, 9, 128)           512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 19, 9, 128)           0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 19, 9, 32)            36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 19, 9, 224)           0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 19, 9, 224)           896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 19, 9, 224)           0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 19, 9, 128)           28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 19, 9, 128)           512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 19, 9, 128)           0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 19, 9, 32)            36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 19, 9, 256)           0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 19, 9, 256)           1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 19, 9, 256)           0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 19, 9, 128)           32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 9, 4, 128)            0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 9, 4, 128)            512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 9, 4, 128)            16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 9, 4, 128)            512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 9, 4, 32)             36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 9, 4, 160)            0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 9, 4, 160)            640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 9, 4, 160)            0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 9, 4, 128)            20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 9, 4, 128)            512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 9, 4, 32)             36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 9, 4, 192)            0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 9, 4, 192)            768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 9, 4, 192)            0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 9, 4, 128)            24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 9, 4, 128)            512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 9, 4, 32)             36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 9, 4, 224)            0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 9, 4, 224)            896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 9, 4, 224)            0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 9, 4, 128)            28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 9, 4, 128)            512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 9, 4, 32)             36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 9, 4, 256)            0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 9, 4, 256)            1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 9, 4, 256)            0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 9, 4, 128)            32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 9, 4, 128)            512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 9, 4, 32)             36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 9, 4, 288)            0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 9, 4, 288)            1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 9, 4, 288)            0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 9, 4, 128)            36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 9, 4, 128)            512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 9, 4, 32)             36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 9, 4, 320)            0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 9, 4, 320)            1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 9, 4, 320)            0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 9, 4, 128)            40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 9, 4, 128)            512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 9, 4, 32)             36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 9, 4, 352)            0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 9, 4, 352)            1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 9, 4, 352)            0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 9, 4, 128)            45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 9, 4, 128)            512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 9, 4, 32)             36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 9, 4, 384)            0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 9, 4, 384)            1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 9, 4, 384)            0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 9, 4, 128)            49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 9, 4, 128)            512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 9, 4, 128)            0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 9, 4, 32)             36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 9, 4, 416)            0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 9, 4, 416)            1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 9, 4, 416)            0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 9, 4, 128)            53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 9, 4, 128)            512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 9, 4, 128)            0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 9, 4, 32)             36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 9, 4, 448)            0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 9, 4, 448)            1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 9, 4, 448)            0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 9, 4, 128)            57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 9, 4, 128)            512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 9, 4, 128)            0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 9, 4, 32)             36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 9, 4, 480)            0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 9, 4, 480)            1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 9, 4, 480)            0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 9, 4, 128)            61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 9, 4, 128)            512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 9, 4, 128)            0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 9, 4, 32)             36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 9, 4, 512)            0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 9, 4, 512)            2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 9, 4, 512)            0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 9, 4, 256)            131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 4, 2, 256)            0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 4, 2, 256)            1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 4, 2, 256)            0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 4, 2, 128)            32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 4, 2, 128)            512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 4, 2, 128)            0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 4, 2, 32)             36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 4, 2, 288)            0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 4, 2, 288)            1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 4, 2, 288)            0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 4, 2, 128)            36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 4, 2, 128)            512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 4, 2, 128)            0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 4, 2, 32)             36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 4, 2, 320)            0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 4, 2, 320)            1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 4, 2, 320)            0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 4, 2, 128)            40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 4, 2, 128)            512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 4, 2, 128)            0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 4, 2, 32)             36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 4, 2, 352)            0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 4, 2, 352)            1408      ['conv4_block3_concat[0][0]']
# ...
# Epoch 6/30
#
# Epoch 6: val_loss did not improve from 0.92003
# 60/60 - 10s - loss: 0.6419 - accuracy: 0.7694 - val_loss: 1.1070 - val_accuracy: 0.6061 - lr: 0.0010 - 10s/epoch - 161ms/step
# Epoch 7/30
#
# Epoch 7: val_loss did not improve from 0.92003
# 60/60 - 7s - loss: 0.6210 - accuracy: 0.7773 - val_loss: 1.0582 - val_accuracy: 0.6283 - lr: 0.0010 - 7s/epoch - 114ms/step
# Epoch 8/30
#
# Epoch 8: val_loss did not improve from 0.92003
# 60/60 - 10s - loss: 0.6170 - accuracy: 0.7763 - val_loss: 1.1572 - val_accuracy: 0.6051 - lr: 0.0010 - 10s/epoch - 162ms/step
# Epoch 9/30
#
# Epoch 9: val_loss did not improve from 0.92003
# 60/60 - 7s - loss: 0.6121 - accuracy: 0.7754 - val_loss: 1.1908 - val_accuracy: 0.5869 - lr: 0.0010 - 7s/epoch - 117ms/step
# Epoch 10/30
#
# Epoch 10: val_loss did not improve from 0.92003
# 60/60 - 10s - loss: 0.6043 - accuracy: 0.7803 - val_loss: 1.1766 - val_accuracy: 0.5889 - lr: 0.0010 - 10s/epoch - 162ms/step
# Epoch 11/30
#
# Epoch 11: val_loss did not improve from 0.92003
# 60/60 - 7s - loss: 0.6192 - accuracy: 0.7779 - val_loss: 1.1895 - val_accuracy: 0.6000 - lr: 0.0010 - 7s/epoch - 117ms/step
# 31/31 [==============================] - 1s 19ms/step - loss: 1.1895 - accuracy: 0.6000
# Validation accuracy: 0.6000000238418579
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
#  40%|████      | 4/10 [11:04<14:31, 145.27s/it]
# Training using fold5 as validation
# Epoch 1/30
#
# Epoch 1: val_loss improved from inf to 0.79465, saving model to model.h5
# 60/60 - 21s - loss: 0.6362 - accuracy: 0.7709 - val_loss: 0.7946 - val_accuracy: 0.7041 - lr: 0.0010 - 21s/epoch - 345ms/step
# Epoch 2/30
#
# Epoch 2: val_loss did not improve from 0.79465
# 60/60 - 9s - loss: 0.6179 - accuracy: 0.7786 - val_loss: 0.8106 - val_accuracy: 0.6944 - lr: 0.0010 - 9s/epoch - 144ms/step
# Epoch 3/30
#
# Epoch 3: val_loss did not improve from 0.79465
# 60/60 - 7s - loss: 0.6174 - accuracy: 0.7778 - val_loss: 0.8337 - val_accuracy: 0.6838 - lr: 0.0010 - 7s/epoch - 124ms/step
# Epoch 4/30
#
# Epoch 4: val_loss did not improve from 0.79465
# 60/60 - 10s - loss: 0.6037 - accuracy: 0.7873 - val_loss: 0.8910 - val_accuracy: 0.6592 - lr: 0.0010 - 10s/epoch - 163ms/step
# Epoch 5/30
#
# Epoch 5: val_loss did not improve from 0.79465
# 60/60 - 7s - loss: 0.6015 - accuracy: 0.7825 - val_loss: 0.8533 - val_accuracy: 0.6699 - lr: 0.0010 - 7s/epoch - 119ms/step
# Epoch 6/30
#
# Epoch 6: val_loss did not improve from 0.79465
# 60/60 - 9s - loss: 0.6056 - accuracy: 0.7808 - val_loss: 0.9187 - val_accuracy: 0.6806 - lr: 0.0010 - 9s/epoch - 145ms/step
# Epoch 7/30
#
# Epoch 7: val_loss did not improve from 0.79465
# 60/60 - 10s - loss: 0.6084 - accuracy: 0.7779 - val_loss: 0.8163 - val_accuracy: 0.6966 - lr: 0.0010 - 10s/epoch - 164ms/step
# Epoch 8/30
#
# Epoch 8: val_loss did not improve from 0.79465
# 60/60 - 7s - loss: 0.5938 - accuracy: 0.7866 - val_loss: 0.8797 - val_accuracy: 0.6677 - lr: 0.0010 - 7s/epoch - 118ms/step
# Epoch 9/30
#
# Epoch 9: val_loss did not improve from 0.79465
# 60/60 - 9s - loss: 0.5997 - accuracy: 0.7821 - val_loss: 0.8973 - val_accuracy: 0.6816 - lr: 0.0010 - 9s/epoch - 155ms/step
# Epoch 10/30
#
# Epoch 10: val_loss did not improve from 0.79465
# 60/60 - 8s - loss: 0.5887 - accuracy: 0.7886 - val_loss: 0.9942 - val_accuracy: 0.6432 - lr: 0.0010 - 8s/epoch - 126ms/step
# Epoch 11/30
#
# Epoch 11: val_loss did not improve from 0.79465
# 60/60 - 9s - loss: 0.5636 - accuracy: 0.7946 - val_loss: 0.9328 - val_accuracy: 0.6741 - lr: 0.0010 - 9s/epoch - 153ms/step
# 30/30 [==============================] - 1s 19ms/step - loss: 0.9328 - accuracy: 0.6741
# Validation accuracy: 0.6741452813148499
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
#  50%|█████     | 5/10 [13:08<11:28, 137.62s/it]
# Training using fold6 as validation
# Epoch 1/30
#
# Epoch 1: val_loss improved from inf to 0.83661, saving model to model.h5
# 61/61 - 23s - loss: 0.5924 - accuracy: 0.7918 - val_loss: 0.8366 - val_accuracy: 0.6877 - lr: 0.0010 - 23s/epoch - 380ms/step
# Epoch 2/30
#
# Epoch 2: val_loss improved from 0.83661 to 0.83473, saving model to model.h5
# 61/61 - 8s - loss: 0.6118 - accuracy: 0.7777 - val_loss: 0.8347 - val_accuracy: 0.6962 - lr: 0.0010 - 8s/epoch - 137ms/step
# Epoch 3/30
#
# Epoch 3: val_loss did not improve from 0.83473
# 61/61 - 9s - loss: 0.5978 - accuracy: 0.7815 - val_loss: 0.9060 - val_accuracy: 0.6792 - lr: 0.0010 - 9s/epoch - 153ms/step
# Epoch 4/30
#
# Epoch 4: val_loss did not improve from 0.83473
# 61/61 - 8s - loss: 0.5812 - accuracy: 0.7912 - val_loss: 0.8693 - val_accuracy: 0.6950 - lr: 0.0010 - 8s/epoch - 139ms/step
# Epoch 5/30
#
# Epoch 5: val_loss did not improve from 0.83473
# 61/61 - 7s - loss: 0.5720 - accuracy: 0.7882 - val_loss: 1.0183 - val_accuracy: 0.6537 - lr: 0.0010 - 7s/epoch - 122ms/step
# Epoch 6/30
#
# Epoch 6: val_loss did not improve from 0.83473
# 61/61 - 10s - loss: 0.5623 - accuracy: 0.7932 - val_loss: 0.8691 - val_accuracy: 0.6889 - lr: 0.0010 - 10s/epoch - 160ms/step
# Epoch 7/30
#
# Epoch 7: val_loss did not improve from 0.83473
# 61/61 - 8s - loss: 0.5763 - accuracy: 0.7903 - val_loss: 0.9564 - val_accuracy: 0.6525 - lr: 0.0010 - 8s/epoch - 130ms/step
# Epoch 8/30
#
# Epoch 8: val_loss did not improve from 0.83473
# 61/61 - 7s - loss: 0.5629 - accuracy: 0.7939 - val_loss: 0.9852 - val_accuracy: 0.6403 - lr: 0.0010 - 7s/epoch - 121ms/step
# Epoch 9/30
#
# Epoch 9: val_loss did not improve from 0.83473
# 61/61 - 10s - loss: 0.5646 - accuracy: 0.7921 - val_loss: 1.0073 - val_accuracy: 0.6646 - lr: 0.0010 - 10s/epoch - 158ms/step
# Epoch 10/30
#
# Epoch 10: val_loss did not improve from 0.83473
# 61/61 - 7s - loss: 0.5603 - accuracy: 0.7945 - val_loss: 0.9506 - val_accuracy: 0.6659 - lr: 0.0010 - 7s/epoch - 115ms/step
# Epoch 11/30
#
# Epoch 11: val_loss did not improve from 0.83473
# 61/61 - 10s - loss: 0.5526 - accuracy: 0.7959 - val_loss: 1.0216 - val_accuracy: 0.6428 - lr: 0.0010 - 10s/epoch - 159ms/step
# Epoch 12/30
#
# Epoch 12: val_loss did not improve from 0.83473
# 61/61 - 12s - loss: 0.5400 - accuracy: 0.8040 - val_loss: 1.0377 - val_accuracy: 0.6622 - lr: 0.0010 - 12s/epoch - 199ms/step
# 26/26 [==============================] - 1s 54ms/step - loss: 1.0377 - accuracy: 0.6622
# Validation accuracy: 0.6622114181518555
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
#  60%|██████    | 6/10 [15:28<09:13, 138.43s/it]
# Training using fold7 as validation
# Epoch 1/30
#
# Epoch 1: val_loss improved from inf to 0.75870, saving model to model.h5
# 61/61 - 30s - loss: 0.5712 - accuracy: 0.7946 - val_loss: 0.7587 - val_accuracy: 0.7208 - lr: 0.0010 - 30s/epoch - 488ms/step
# Epoch 2/30
#
# Epoch 2: val_loss did not improve from 0.75870
# 61/61 - 10s - loss: 0.5584 - accuracy: 0.7955 - val_loss: 0.9078 - val_accuracy: 0.6611 - lr: 0.0010 - 10s/epoch - 168ms/step
# Epoch 3/30
#
# Epoch 3: val_loss did not improve from 0.75870
# 61/61 - 7s - loss: 0.5499 - accuracy: 0.8022 - val_loss: 0.8370 - val_accuracy: 0.6945 - lr: 0.0010 - 7s/epoch - 119ms/step
# Epoch 4/30
#
# Epoch 4: val_loss did not improve from 0.75870
# 61/61 - 9s - loss: 0.5556 - accuracy: 0.7938 - val_loss: 0.8911 - val_accuracy: 0.6611 - lr: 0.0010 - 9s/epoch - 154ms/step
# Epoch 5/30
#
# Epoch 5: val_loss did not improve from 0.75870
# 61/61 - 9s - loss: 0.5408 - accuracy: 0.8075 - val_loss: 0.8667 - val_accuracy: 0.6909 - lr: 0.0010 - 9s/epoch - 149ms/step
# Epoch 6/30
#
# Epoch 6: val_loss did not improve from 0.75870
# 61/61 - 8s - loss: 0.5388 - accuracy: 0.8069 - val_loss: 0.9088 - val_accuracy: 0.6838 - lr: 0.0010 - 8s/epoch - 137ms/step
# Epoch 7/30
#
# Epoch 7: val_loss did not improve from 0.75870
# 61/61 - 10s - loss: 0.5283 - accuracy: 0.8070 - val_loss: 0.8920 - val_accuracy: 0.7029 - lr: 0.0010 - 10s/epoch - 171ms/step
# Epoch 8/30
#
# Epoch 8: val_loss did not improve from 0.75870
# 61/61 - 9s - loss: 0.5212 - accuracy: 0.8099 - val_loss: 0.9357 - val_accuracy: 0.6695 - lr: 0.0010 - 9s/epoch - 145ms/step
# Epoch 9/30
#
# Epoch 9: val_loss did not improve from 0.75870
# 61/61 - 9s - loss: 0.5283 - accuracy: 0.8059 - val_loss: 0.9705 - val_accuracy: 0.6420 - lr: 0.0010 - 9s/epoch - 150ms/step
# Epoch 10/30
#
# Epoch 10: val_loss did not improve from 0.75870
# 61/61 - 7s - loss: 0.5287 - accuracy: 0.8096 - val_loss: 0.9363 - val_accuracy: 0.6718 - lr: 0.0010 - 7s/epoch - 121ms/step
# Epoch 11/30
#
# Epoch 11: val_loss did not improve from 0.75870
# 61/61 - 10s - loss: 0.5232 - accuracy: 0.8094 - val_loss: 0.8677 - val_accuracy: 0.6826 - lr: 0.0010 - 10s/epoch - 160ms/step
# 27/27 [==============================] - 1s 19ms/step - loss: 0.8677 - accuracy: 0.6826
# Validation accuracy: 0.6825775504112244
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
#  70%|███████   | 7/10 [17:57<07:05, 141.80s/it]
# Training using fold8 as validation
# Epoch 1/30
#
# Epoch 1: val_loss improved from inf to 0.73640, saving model to model.h5
# 61/61 - 21s - loss: 0.5543 - accuracy: 0.7966 - val_loss: 0.7364 - val_accuracy: 0.7233 - lr: 0.0010 - 21s/epoch - 344ms/step
# Epoch 2/30
#
# Epoch 2: val_loss did not improve from 0.73640
# 61/61 - 10s - loss: 0.5420 - accuracy: 0.8041 - val_loss: 0.7985 - val_accuracy: 0.7258 - lr: 0.0010 - 10s/epoch - 169ms/step
# Epoch 3/30
#
# Epoch 3: val_loss did not improve from 0.73640
# 61/61 - 11s - loss: 0.5238 - accuracy: 0.8134 - val_loss: 0.8226 - val_accuracy: 0.7035 - lr: 0.0010 - 11s/epoch - 181ms/step
# Epoch 4/30
#
# Epoch 4: val_loss did not improve from 0.73640
# 61/61 - 8s - loss: 0.5263 - accuracy: 0.8111 - val_loss: 0.8634 - val_accuracy: 0.6911 - lr: 0.0010 - 8s/epoch - 123ms/step
# Epoch 5/30
#
# Epoch 5: val_loss did not improve from 0.73640
# 61/61 - 10s - loss: 0.5106 - accuracy: 0.8117 - val_loss: 0.7436 - val_accuracy: 0.7345 - lr: 0.0010 - 10s/epoch - 164ms/step
# Epoch 6/30
#
# Epoch 6: val_loss did not improve from 0.73640
# 61/61 - 7s - loss: 0.5213 - accuracy: 0.8132 - val_loss: 0.8437 - val_accuracy: 0.6973 - lr: 0.0010 - 7s/epoch - 118ms/step
# Epoch 7/30
#
# Epoch 7: val_loss did not improve from 0.73640
# 61/61 - 10s - loss: 0.5240 - accuracy: 0.8061 - val_loss: 0.9558 - val_accuracy: 0.6749 - lr: 0.0010 - 10s/epoch - 164ms/step
# Epoch 8/30
#
# Epoch 8: val_loss did not improve from 0.73640
# 61/61 - 7s - loss: 0.5261 - accuracy: 0.8080 - val_loss: 0.8382 - val_accuracy: 0.6861 - lr: 0.0010 - 7s/epoch - 120ms/step
# Epoch 9/30
#
# Epoch 9: val_loss did not improve from 0.73640
# 61/61 - 8s - loss: 0.4962 - accuracy: 0.8232 - val_loss: 0.8360 - val_accuracy: 0.6973 - lr: 0.0010 - 8s/epoch - 136ms/step
# Epoch 10/30
#
# Epoch 10: val_loss did not improve from 0.73640
# 61/61 - 9s - loss: 0.5011 - accuracy: 0.8179 - val_loss: 0.7954 - val_accuracy: 0.7146 - lr: 0.0010 - 9s/epoch - 150ms/step
# Epoch 11/30
#
# Epoch 11: val_loss did not improve from 0.73640
# 61/61 - 8s - loss: 0.5273 - accuracy: 0.8096 - val_loss: 0.9567 - val_accuracy: 0.6725 - lr: 0.0010 - 8s/epoch - 126ms/step
# 26/26 [==============================] - 1s 20ms/step - loss: 0.9567 - accuracy: 0.6725
# Validation accuracy: 0.6724565625190735
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
#  80%|████████  | 8/10 [20:25<04:47, 143.66s/it]
# Training using fold9 as validation
# Epoch 1/30
#
# Epoch 1: val_loss improved from inf to 0.61365, saving model to model.h5
# 61/61 - 22s - loss: 0.5416 - accuracy: 0.8032 - val_loss: 0.6136 - val_accuracy: 0.7635 - lr: 0.0010 - 22s/epoch - 356ms/step
# Epoch 2/30
#
# Epoch 2: val_loss did not improve from 0.61365
# 61/61 - 9s - loss: 0.5160 - accuracy: 0.8156 - val_loss: 0.6966 - val_accuracy: 0.7414 - lr: 0.0010 - 9s/epoch - 140ms/step
# Epoch 3/30
#
# Epoch 3: val_loss did not improve from 0.61365
# 61/61 - 8s - loss: 0.5101 - accuracy: 0.8166 - val_loss: 0.6459 - val_accuracy: 0.7708 - lr: 0.0010 - 8s/epoch - 126ms/step
# Epoch 4/30
#
# Epoch 4: val_loss did not improve from 0.61365
# 61/61 - 10s - loss: 0.5136 - accuracy: 0.8145 - val_loss: 0.6568 - val_accuracy: 0.7549 - lr: 0.0010 - 10s/epoch - 162ms/step
# Epoch 5/30
#
# Epoch 5: val_loss did not improve from 0.61365
# 61/61 - 7s - loss: 0.5041 - accuracy: 0.8173 - val_loss: 0.7619 - val_accuracy: 0.7365 - lr: 0.0010 - 7s/epoch - 118ms/step
# Epoch 6/30
#
# Epoch 6: val_loss did not improve from 0.61365
# 61/61 - 8s - loss: 0.5042 - accuracy: 0.8125 - val_loss: 0.7436 - val_accuracy: 0.7328 - lr: 0.0010 - 8s/epoch - 132ms/step
# Epoch 7/30
#
# Epoch 7: val_loss did not improve from 0.61365
# 61/61 - 9s - loss: 0.4921 - accuracy: 0.8247 - val_loss: 0.8202 - val_accuracy: 0.7120 - lr: 0.0010 - 9s/epoch - 154ms/step
# Epoch 8/30
#
# Epoch 8: val_loss did not improve from 0.61365
# 61/61 - 8s - loss: 0.5036 - accuracy: 0.8130 - val_loss: 0.8736 - val_accuracy: 0.7120 - lr: 0.0010 - 8s/epoch - 124ms/step
# Epoch 9/30
#
# Epoch 9: val_loss did not improve from 0.61365
# 61/61 - 10s - loss: 0.4998 - accuracy: 0.8199 - val_loss: 0.8502 - val_accuracy: 0.7206 - lr: 0.0010 - 10s/epoch - 158ms/step
# Epoch 10/30
#
# Epoch 10: val_loss did not improve from 0.61365
# 61/61 - 7s - loss: 0.4895 - accuracy: 0.8214 - val_loss: 0.8116 - val_accuracy: 0.7194 - lr: 0.0010 - 7s/epoch - 120ms/step
# Epoch 11/30
#
# Epoch 11: val_loss did not improve from 0.61365
# 61/61 - 10s - loss: 0.4852 - accuracy: 0.8270 - val_loss: 0.8120 - val_accuracy: 0.7365 - lr: 0.0010 - 10s/epoch - 163ms/step
# 26/26 [==============================] - 1s 20ms/step - loss: 0.8120 - accuracy: 0.7365
# Validation accuracy: 0.7365196347236633
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
#  90%|█████████ | 9/10 [22:31<02:18, 138.19s/it]
# Training using fold10 as validation
# Epoch 1/30
#
# Epoch 1: val_loss improved from inf to 0.60118, saving model to model.h5
# 61/61 - 22s - loss: 0.4990 - accuracy: 0.8249 - val_loss: 0.6012 - val_accuracy: 0.7778 - lr: 0.0010 - 22s/epoch - 368ms/step
# Epoch 2/30
#
# Epoch 2: val_loss did not improve from 0.60118
# 61/61 - 7s - loss: 0.4930 - accuracy: 0.8205 - val_loss: 0.6696 - val_accuracy: 0.7587 - lr: 0.0010 - 7s/epoch - 121ms/step
# Epoch 3/30
#
# Epoch 3: val_loss did not improve from 0.60118
# 61/61 - 10s - loss: 0.4857 - accuracy: 0.8227 - val_loss: 0.7528 - val_accuracy: 0.7264 - lr: 0.0010 - 10s/epoch - 162ms/step
# Epoch 4/30
#
# Epoch 4: val_loss did not improve from 0.60118
# 61/61 - 7s - loss: 0.4872 - accuracy: 0.8198 - val_loss: 0.7095 - val_accuracy: 0.7527 - lr: 0.0010 - 7s/epoch - 121ms/step
# Epoch 5/30
#
# Epoch 5: val_loss did not improve from 0.60118
# 61/61 - 8s - loss: 0.4743 - accuracy: 0.8254 - val_loss: 0.7043 - val_accuracy: 0.7515 - lr: 0.0010 - 8s/epoch - 124ms/step
# Epoch 6/30
#
# Epoch 6: val_loss did not improve from 0.60118
# 61/61 - 10s - loss: 0.4719 - accuracy: 0.8294 - val_loss: 0.7742 - val_accuracy: 0.7395 - lr: 0.0010 - 10s/epoch - 163ms/step
# Epoch 7/30
#
# Epoch 7: val_loss did not improve from 0.60118
# 61/61 - 8s - loss: 0.4957 - accuracy: 0.8194 - val_loss: 0.8435 - val_accuracy: 0.7157 - lr: 0.0010 - 8s/epoch - 129ms/step
# Epoch 8/30
#
# Epoch 8: val_loss did not improve from 0.60118
# 61/61 - 8s - loss: 0.4791 - accuracy: 0.8275 - val_loss: 0.7891 - val_accuracy: 0.7276 - lr: 0.0010 - 8s/epoch - 125ms/step
# Epoch 9/30
#
# Epoch 9: val_loss did not improve from 0.60118
# 61/61 - 10s - loss: 0.4701 - accuracy: 0.8267 - val_loss: 0.7725 - val_accuracy: 0.7336 - lr: 0.0010 - 10s/epoch - 163ms/step
# Epoch 10/30
#
# Epoch 10: val_loss did not improve from 0.60118
# 61/61 - 8s - loss: 0.4884 - accuracy: 0.8216 - val_loss: 0.7999 - val_accuracy: 0.7312 - lr: 0.0010 - 8s/epoch - 129ms/step
# Epoch 11/30
#
# Epoch 11: val_loss did not improve from 0.60118
# 61/61 - 7s - loss: 0.4720 - accuracy: 0.8298 - val_loss: 0.8163 - val_accuracy: 0.7180 - lr: 0.0010 - 7s/epoch - 122ms/step
# 27/27 [==============================] - 1s 30ms/step - loss: 0.8163 - accuracy: 0.7180
# Validation accuracy: 0.7180406451225281
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# 100%|██████████| 10/10 [24:42<00:00, 148.20s/it]
# List of scores[0.550973653793335, 0.6261261105537415, 0.6043243408203125, 0.6000000238418579, 0.6741452813148499, 0.6622114181518555, 0.6825775504112244, 0.6724565625190735, 0.7365196347236633, 0.7180406451225281]
# Average accuracy: 0.6527375221252442
# Trained only the last -10 layers
# 27/27 [==============================] - 4s 26ms/step
# Total-test-data; 837 	accurately-predicted-data: 601 	 wrongly-predicted-data:  236
# Accuracy: 71.804 %
