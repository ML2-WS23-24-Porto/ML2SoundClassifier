# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
import tqdm
import pandas as pd
import keras
import time, warnings
import tensorflow
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.metrics import confusion_matrix
import keras_tuner
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import (
    Dense,
    Conv1D,
    MaxPooling1D,
    BatchNormalization,
    Dropout,
    Flatten,
    Conv2D,
    MaxPool2D,
    Activation,
    GlobalAveragePooling2D,
)
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

warnings.filterwarnings("ignore")

# %%
#Specify paths here
root_folder = r"/content/drive/MyDrive/UrbanSound8kv2/Data_extracted/both"
metadata = pd.read_csv('/content/drive/MyDrive/UrbanSound8kv2/Data_extracted/processed_data.csv')

# %%
#class for plotting
class PlotLearning(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.metrics = {}
        for metric in logs:
            self.metrics[metric] = []

    def on_epoch_end(self, epoch, logs={}):
        # Storing metrics
        for metric in logs:
            if metric in self.metrics:
                self.metrics[metric].append(logs.get(metric))
            else:
                self.metrics[metric] = [logs.get(metric)]

        # Plotting
        metrics = [x for x in logs if 'val' not in x]

        f, axs = plt.subplots(1, len(metrics), figsize=(15, 5))

        for i, metric in enumerate(metrics):
            axs[i].plot(range(1, epoch + 2),
                        self.metrics[metric],
                        label=metric)
            if logs['val_' + metric]:
                axs[i].plot(range(1, epoch + 2),
                            self.metrics['val_' + metric],
                            label='val_' + metric)

            axs[i].legend()
            axs[i].grid()

        plt.tight_layout()
        plt.show()

def normalize(clip):
    normalized_clip = (clip - np.min(clip)) / (np.max(clip) - np.min(clip))
    return normalized_clip

def conv_array(root_folder):
    shape = (76, 33)
    folds = {}
    for fold in range(1, 11):
        fold_path = os.path.join(root_folder, f"fold{fold}")
        image_data = []
        all_labels = []
        if not os.path.exists(fold_path):
            continue  # Skip if the folder doesn't exist
        for filename in tqdm.tqdm(os.listdir(fold_path)):
            if filename.endswith(".png"):
                image_path = os.path.join(fold_path, filename)
                image = Image.open(image_path)
                new_filename = filename.replace('.png', '.wav')
                row_num = metadata[metadata['slice_file_name'] == new_filename].index
                if not row_num.empty:
                    image_array = np.array(image)
                    if not image_array.shape == (shape):
                      continue
                    image_array = normalize(image_array)
                    image_array = np.ndarray(shape=(image_array.shape[0], image_array.shape[1], 1), dtype= np.uint8)
                    label = metadata.iloc[row_num]['labelID'].values[0]
                    #print(f'Double check: image {new_filename} has label {label}')
                    all_labels.append(label)
                    image_data.append(image_array)
                else:
                    print(f'{new_filename} not found')
                    continue
        image_data = np.array(image_data)
        all_labels = np.array(all_labels)
        all_labels = to_categorical(all_labels, num_classes=10)
        #converting numpy arrays to tf.tensor for GPU optimization
        image_data_tensor = tensorflow.convert_to_tensor(image_data)
        all_labels_tensor = tensorflow.convert_to_tensor(all_labels)
        image_data_tensor = tensorflow.image.grayscale_to_rgb(image_data_tensor)
        folds[f"fold{fold}"] = [image_data_tensor, all_labels_tensor]
    return folds



data = conv_array(root_folder)
input_shape = data['fold1'][0].shape
print(input_shape)
# Out:
# 100%|██████████| 873/873 [00:16<00:00, 53.86it/s]
# 100%|██████████| 888/888 [00:20<00:00, 42.44it/s]
# 100%|██████████| 925/925 [00:25<00:00, 36.43it/s]
# 100%|██████████| 990/990 [00:27<00:00, 35.54it/s]
# 100%|██████████| 936/936 [00:25<00:00, 36.67it/s]
# 100%|██████████| 823/823 [00:14<00:00, 58.77it/s]
# 100%|██████████| 838/838 [00:15<00:00, 52.69it/s]
# 100%|██████████| 806/806 [00:13<00:00, 60.01it/s]
# 100%|██████████| 816/816 [00:12<00:00, 62.96it/s]
# 100%|██████████| 837/837 [00:14<00:00, 59.29it/s]
# (873, 76, 33, 3)

# %%
print(input_shape)
input_shape2 = input_shape[1:4]
print(input_shape2)
# Out:
# (873, 76, 33, 3)
# (76, 33, 3)

# %%
tensorflow.keras.backend.clear_session()

metric = 'accuracy' #evaluation metric
loss= 'categorical_crossentropy' #loss function

#training parameters
num_epoch = 50
batch_size = 128

#We turned off early stopping for the sake of plotting
early_stop = 100 # early stoppping after 3 epochs with no improvement of test data

trainable_layers = -8 #trainable layers needs a minus infront
dropout_rate = 0.5
learning_rate = 0.001


def model_k_cross(data):
    list_scores = []
    Ytrue_list = []
    Ypred_list = []
    for fold_name, fold_data in tqdm.tqdm(data.items()):
        tensorflow.keras.backend.clear_session()

        #Densenet121 model using pretrained weights from imagenet
        model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=input_shape[1:4], classes=10)

        x=model_d.output
        x= GlobalAveragePooling2D()(x)
        x= BatchNormalization()(x)
        x= Dropout(dropout_rate)(x)
        x= Dense(1024,activation='relu')(x)
        x= Dropout(dropout_rate)(x)
        x= Dense(512,activation='relu')(x)
        x= Dropout(dropout_rate)(x)
        x= Dense(256,activation='relu')(x)
        x= BatchNormalization()(x)
        x= Dropout(dropout_rate)(x)
        preds=Dense(10,activation='softmax')(x) #FC-layer
        model=Model(inputs=model_d.input,outputs=preds)

        #instance of Adam optimizer
        Adam = keras.optimizers.Adam(learning_rate=learning_rate)


        #To avoid the problem of overfitting, avoid training the entire network. layer.trainable=False will freeze all the layers, keeping only the last eight layers (FC) to detect edges and blobs in the image. Once the model is fitted well, it can be fine-tuned by using layer.trainable=True.
        for layer in model.layers[:trainable_layers]:
            layer.trainable=False
        for layer in model.layers[trainable_layers:]:
            layer.trainable=True


        #Splitting data
        print(f"Training using {fold_name} as validation")
        X_val, y_val = fold_data[0], fold_data[1]
        X_train = []
        y_train = []

        for other_fold_name, other_fold_data in data.items():
            if other_fold_name == fold_name:
                continue

            X = other_fold_data[0]
            y = other_fold_data[1]
            X_train.extend(X)
            y_train.extend(y)

        X_train = np.array(X_train)
        y_train = np.array(y_train)



        model.compile(optimizer=Adam,loss='categorical_crossentropy',metrics=['accuracy'])
        EarlyStoppingCallback = tensorflow.keras.callbacks.EarlyStopping(monitor='val_loss', patience=early_stop)


        #If the model sees no change in validation loss the ReduceLROnPlateau function will reduce the learning rate, which often benefits the model.
        anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
        checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)


        history = model.fit(X_train, y_train,
                        batch_size=batch_size,
                       steps_per_epoch=X_train.shape[0] //128,
                       epochs=num_epoch,
                       verbose=2,
                       callbacks=[anne, checkpoint, EarlyStoppingCallback],
                       validation_data=(X_val, y_val))

        # Evaluation
        scores = model.evaluate(X_val, y_val)
        print("Validation accuracy:", scores[1])
        list_scores.append(scores[1])

        #Storing values
        Ypred_it = model.predict(X_val)
        Ypred_it = np.argmax(Ypred_it, axis=1)
        Ytrue_it = np.argmax(y_val, axis=1)
        Ytrue_list.extend(Ytrue_it.tolist())  # Append predictions to lists
        Ypred_list.extend(Ypred_it.tolist())


        # Plot training history - loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title(f"Training Loss - {fold_name} as validation")
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Training Loss', 'Validation Loss'], loc='upper left')
        plt.show()

        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title(f"Accuracy - {fold_name} as validation")
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Training accuracy', 'Validation accuracy'], loc='upper left')
        plt.show()


    average_acc = sum(list_scores) / len(list_scores)
    list_scores_array = np.array(list_scores)
    std = np.std(list_scores_array)
    print(f'List of scores{list_scores}')
    print(f'Average accuracy: {average_acc} with standard deviation {std}')
    print(f'Trained only the last {trainable_layers} layers')
    Ytrue = np.array(Ytrue_list)
    Ypred = np.array(Ypred_list)

    label = ['air_conditioning', 'car_horn', 'children_playing', 'dog_bark', 'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 'siren', 'street_music']

    #Confusion matrix
    cm = confusion_matrix(Ytrue, Ypred)
    plt.figure(figsize=(12, 12))
    ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
    ax.set_ylabel('Actual', fontsize=20)
    ax.set_xlabel('Predicted', fontsize=20)


model_k_cross(data)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Training using fold1 as validation
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 2.85349, saving model to model.h5
# 61/61 - 15s - loss: 3.0886 - accuracy: 0.1468 - val_loss: 2.8535 - val_accuracy: 0.2337 - lr: 0.0010 - 15s/epoch - 243ms/step
# Epoch 2/50
#
# Epoch 2: val_loss improved from 2.85349 to 1.88073, saving model to model.h5
# 61/61 - 3s - loss: 2.5538 - accuracy: 0.1944 - val_loss: 1.8807 - val_accuracy: 0.2749 - lr: 0.0010 - 3s/epoch - 51ms/step
# Epoch 3/50
#
# Epoch 3: val_loss improved from 1.88073 to 1.64439, saving model to model.h5
# 61/61 - 3s - loss: 2.2814 - accuracy: 0.2346 - val_loss: 1.6444 - val_accuracy: 0.4284 - lr: 0.0010 - 3s/epoch - 46ms/step
# Epoch 4/50
#
# Epoch 4: val_loss improved from 1.64439 to 1.61129, saving model to model.h5
# 61/61 - 3s - loss: 2.0639 - accuracy: 0.2786 - val_loss: 1.6113 - val_accuracy: 0.3963 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 5/50
#
# Epoch 5: val_loss improved from 1.61129 to 1.51852, saving model to model.h5
# 61/61 - 3s - loss: 1.9517 - accuracy: 0.3058 - val_loss: 1.5185 - val_accuracy: 0.4227 - lr: 0.0010 - 3s/epoch - 52ms/step
# Epoch 6/50
#
# Epoch 6: val_loss improved from 1.51852 to 1.49850, saving model to model.h5
# 61/61 - 4s - loss: 1.8210 - accuracy: 0.3487 - val_loss: 1.4985 - val_accuracy: 0.4399 - lr: 0.0010 - 4s/epoch - 62ms/step
# Epoch 7/50
#
# Epoch 7: val_loss improved from 1.49850 to 1.47027, saving model to model.h5
# 61/61 - 3s - loss: 1.7688 - accuracy: 0.3659 - val_loss: 1.4703 - val_accuracy: 0.4353 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 8/50
#
# Epoch 8: val_loss improved from 1.47027 to 1.46350, saving model to model.h5
# 61/61 - 3s - loss: 1.7159 - accuracy: 0.3848 - val_loss: 1.4635 - val_accuracy: 0.4387 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 9/50
#
# Epoch 9: val_loss improved from 1.46350 to 1.45105, saving model to model.h5
# 61/61 - 3s - loss: 1.6737 - accuracy: 0.3972 - val_loss: 1.4511 - val_accuracy: 0.4399 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 10/50
#
# Epoch 10: val_loss improved from 1.45105 to 1.41996, saving model to model.h5
# 61/61 - 3s - loss: 1.6154 - accuracy: 0.4228 - val_loss: 1.4200 - val_accuracy: 0.4616 - lr: 0.0010 - 3s/epoch - 53ms/step
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 1.41996
# 61/61 - 3s - loss: 1.6195 - accuracy: 0.4201 - val_loss: 1.4251 - val_accuracy: 0.5006 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 12/50
#
# Epoch 12: val_loss improved from 1.41996 to 1.39863, saving model to model.h5
# 61/61 - 3s - loss: 1.5707 - accuracy: 0.4376 - val_loss: 1.3986 - val_accuracy: 0.4731 - lr: 0.0010 - 3s/epoch - 51ms/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 1.39863
# 61/61 - 2s - loss: 1.5490 - accuracy: 0.4479 - val_loss: 1.4104 - val_accuracy: 0.4422 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 14/50
#
# Epoch 14: val_loss improved from 1.39863 to 1.38593, saving model to model.h5
# 61/61 - 3s - loss: 1.5515 - accuracy: 0.4473 - val_loss: 1.3859 - val_accuracy: 0.4868 - lr: 0.0010 - 3s/epoch - 46ms/step
# Epoch 15/50
#
# Epoch 15: val_loss improved from 1.38593 to 1.35308, saving model to model.h5
# 61/61 - 3s - loss: 1.5145 - accuracy: 0.4609 - val_loss: 1.3531 - val_accuracy: 0.5200 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 16/50
#
# Epoch 16: val_loss improved from 1.35308 to 1.34556, saving model to model.h5
# 61/61 - 3s - loss: 1.4995 - accuracy: 0.4645 - val_loss: 1.3456 - val_accuracy: 0.5223 - lr: 0.0010 - 3s/epoch - 55ms/step
# Epoch 17/50
#
# Epoch 17: val_loss improved from 1.34556 to 1.31128, saving model to model.h5
# 61/61 - 3s - loss: 1.4739 - accuracy: 0.4712 - val_loss: 1.3113 - val_accuracy: 0.5326 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 1.31128
# 61/61 - 2s - loss: 1.4619 - accuracy: 0.4809 - val_loss: 1.3356 - val_accuracy: 0.5063 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 1.31128
# 61/61 - 2s - loss: 1.4364 - accuracy: 0.4957 - val_loss: 1.3634 - val_accuracy: 0.4983 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 1.31128
# 61/61 - 2s - loss: 1.4439 - accuracy: 0.4805 - val_loss: 1.3119 - val_accuracy: 0.5361 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 1.31128
# 61/61 - 2s - loss: 1.4044 - accuracy: 0.5038 - val_loss: 1.3517 - val_accuracy: 0.4754 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 22/50
#
# Epoch 22: val_loss improved from 1.31128 to 1.30784, saving model to model.h5
# 61/61 - 3s - loss: 1.4368 - accuracy: 0.4834 - val_loss: 1.3078 - val_accuracy: 0.5475 - lr: 0.0010 - 3s/epoch - 55ms/step
# Epoch 23/50
#
# Epoch 23: val_loss improved from 1.30784 to 1.27703, saving model to model.h5
# 61/61 - 3s - loss: 1.4003 - accuracy: 0.5054 - val_loss: 1.2770 - val_accuracy: 0.5533 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 1.27703
# 61/61 - 3s - loss: 1.4106 - accuracy: 0.4993 - val_loss: 1.2970 - val_accuracy: 0.5384 - lr: 0.0010 - 3s/epoch - 41ms/step
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 1.27703
# 61/61 - 2s - loss: 1.3921 - accuracy: 0.5087 - val_loss: 1.2996 - val_accuracy: 0.5727 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 1.27703
# 61/61 - 2s - loss: 1.3876 - accuracy: 0.5094 - val_loss: 1.2858 - val_accuracy: 0.5441 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 1.27703
# 61/61 - 2s - loss: 1.3630 - accuracy: 0.5182 - val_loss: 1.2917 - val_accuracy: 0.5659 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 1.27703
# 61/61 - 2s - loss: 1.3591 - accuracy: 0.5263 - val_loss: 1.2914 - val_accuracy: 0.5682 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 29/50
#
# Epoch 29: val_loss improved from 1.27703 to 1.25947, saving model to model.h5
# 61/61 - 3s - loss: 1.3652 - accuracy: 0.5265 - val_loss: 1.2595 - val_accuracy: 0.5727 - lr: 0.0010 - 3s/epoch - 56ms/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 1.25947
# 61/61 - 2s - loss: 1.3378 - accuracy: 0.5285 - val_loss: 1.2824 - val_accuracy: 0.5521 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 1.25947
# 61/61 - 2s - loss: 1.3340 - accuracy: 0.5305 - val_loss: 1.2887 - val_accuracy: 0.5361 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 1.25947
# 61/61 - 2s - loss: 1.3386 - accuracy: 0.5325 - val_loss: 1.2860 - val_accuracy: 0.5498 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 1.25947
# 61/61 - 2s - loss: 1.3250 - accuracy: 0.5329 - val_loss: 1.2868 - val_accuracy: 0.5258 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 1.25947
# 61/61 - 2s - loss: 1.3273 - accuracy: 0.5261 - val_loss: 1.3182 - val_accuracy: 0.5029 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 1.25947
# 61/61 - 3s - loss: 1.3048 - accuracy: 0.5424 - val_loss: 1.2613 - val_accuracy: 0.5739 - lr: 0.0010 - 3s/epoch - 41ms/step
# Epoch 36/50
#
# Epoch 36: val_loss improved from 1.25947 to 1.25783, saving model to model.h5
# 61/61 - 3s - loss: 1.2880 - accuracy: 0.5439 - val_loss: 1.2578 - val_accuracy: 0.5624 - lr: 0.0010 - 3s/epoch - 52ms/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 1.25783
# 61/61 - 2s - loss: 1.2880 - accuracy: 0.5471 - val_loss: 1.3146 - val_accuracy: 0.5292 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 38/50
#
# Epoch 38: val_loss improved from 1.25783 to 1.24580, saving model to model.h5
# 61/61 - 3s - loss: 1.2872 - accuracy: 0.5509 - val_loss: 1.2458 - val_accuracy: 0.5407 - lr: 0.0010 - 3s/epoch - 46ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 1.24580
# 61/61 - 2s - loss: 1.2981 - accuracy: 0.5389 - val_loss: 1.2748 - val_accuracy: 0.5521 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 1.24580
# 61/61 - 2s - loss: 1.2681 - accuracy: 0.5583 - val_loss: 1.2810 - val_accuracy: 0.5544 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 1.24580
# 61/61 - 3s - loss: 1.2670 - accuracy: 0.5568 - val_loss: 1.2756 - val_accuracy: 0.5498 - lr: 0.0010 - 3s/epoch - 41ms/step
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 1.24580
# 61/61 - 2s - loss: 1.2734 - accuracy: 0.5500 - val_loss: 1.2733 - val_accuracy: 0.5166 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 1.24580
# 61/61 - 2s - loss: 1.2587 - accuracy: 0.5581 - val_loss: 1.2578 - val_accuracy: 0.5510 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 1.24580
# 61/61 - 2s - loss: 1.2547 - accuracy: 0.5616 - val_loss: 1.3150 - val_accuracy: 0.5304 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 1.24580
# 61/61 - 2s - loss: 1.2405 - accuracy: 0.5684 - val_loss: 1.2679 - val_accuracy: 0.5441 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 1.24580
# 61/61 - 2s - loss: 1.2532 - accuracy: 0.5671 - val_loss: 1.2508 - val_accuracy: 0.5544 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 1.24580
# 61/61 - 2s - loss: 1.2339 - accuracy: 0.5697 - val_loss: 1.2655 - val_accuracy: 0.5372 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 1.24580
# 61/61 - 2s - loss: 1.2249 - accuracy: 0.5735 - val_loss: 1.2787 - val_accuracy: 0.5578 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 49/50
#
# Epoch 49: val_loss improved from 1.24580 to 1.22693, saving model to model.h5
# 61/61 - 3s - loss: 1.2083 - accuracy: 0.5709 - val_loss: 1.2269 - val_accuracy: 0.5979 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 1.22693
# 61/61 - 2s - loss: 1.2244 - accuracy: 0.5735 - val_loss: 1.2319 - val_accuracy: 0.5922 - lr: 0.0010 - 2s/epoch - 37ms/step
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2319 - accuracy: 0.5922
# Validation accuracy: 0.5922107696533203
# 28/28 [==============================] - 2s 19ms/step
#  10%|█         | 1/10 [02:38<23:42, 158.07s/it]
# Training using fold2 as validation
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 2.63944, saving model to model.h5
# 61/61 - 15s - loss: 3.0293 - accuracy: 0.1545 - val_loss: 2.6394 - val_accuracy: 0.1858 - lr: 0.0010 - 15s/epoch - 251ms/step
# Epoch 2/50
#
# Epoch 2: val_loss improved from 2.63944 to 1.97060, saving model to model.h5
# 61/61 - 3s - loss: 2.4789 - accuracy: 0.2106 - val_loss: 1.9706 - val_accuracy: 0.2939 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 3/50
#
# Epoch 3: val_loss improved from 1.97060 to 1.72944, saving model to model.h5
# 61/61 - 3s - loss: 2.1786 - accuracy: 0.2615 - val_loss: 1.7294 - val_accuracy: 0.4358 - lr: 0.0010 - 3s/epoch - 46ms/step
# Epoch 4/50
#
# Epoch 4: val_loss improved from 1.72944 to 1.63863, saving model to model.h5
# 61/61 - 3s - loss: 2.0236 - accuracy: 0.2911 - val_loss: 1.6386 - val_accuracy: 0.4020 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 5/50
#
# Epoch 5: val_loss improved from 1.63863 to 1.61084, saving model to model.h5
# 61/61 - 3s - loss: 1.8861 - accuracy: 0.3344 - val_loss: 1.6108 - val_accuracy: 0.4493 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 6/50
#
# Epoch 6: val_loss improved from 1.61084 to 1.60763, saving model to model.h5
# 61/61 - 4s - loss: 1.8002 - accuracy: 0.3526 - val_loss: 1.6076 - val_accuracy: 0.4516 - lr: 0.0010 - 4s/epoch - 69ms/step
# Epoch 7/50
#
# Epoch 7: val_loss improved from 1.60763 to 1.53436, saving model to model.h5
# 61/61 - 3s - loss: 1.7080 - accuracy: 0.3919 - val_loss: 1.5344 - val_accuracy: 0.4775 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 1.53436
# 61/61 - 2s - loss: 1.7220 - accuracy: 0.3787 - val_loss: 1.5494 - val_accuracy: 0.4595 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 1.53436
# 61/61 - 2s - loss: 1.6480 - accuracy: 0.4138 - val_loss: 1.5492 - val_accuracy: 0.4628 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 10/50
#
# Epoch 10: val_loss improved from 1.53436 to 1.51817, saving model to model.h5
# 61/61 - 3s - loss: 1.6265 - accuracy: 0.4155 - val_loss: 1.5182 - val_accuracy: 0.4752 - lr: 0.0010 - 3s/epoch - 55ms/step
# Epoch 11/50
#
# Epoch 11: val_loss improved from 1.51817 to 1.47061, saving model to model.h5
# 61/61 - 3s - loss: 1.6021 - accuracy: 0.4313 - val_loss: 1.4706 - val_accuracy: 0.5056 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 1.47061
# 61/61 - 2s - loss: 1.5635 - accuracy: 0.4413 - val_loss: 1.5117 - val_accuracy: 0.4628 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 13/50
#
# Epoch 13: val_loss improved from 1.47061 to 1.46650, saving model to model.h5
# 61/61 - 3s - loss: 1.5469 - accuracy: 0.4474 - val_loss: 1.4665 - val_accuracy: 0.4673 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 14/50
#
# Epoch 14: val_loss improved from 1.46650 to 1.44410, saving model to model.h5
# 61/61 - 3s - loss: 1.5203 - accuracy: 0.4565 - val_loss: 1.4441 - val_accuracy: 0.5034 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 15/50
#
# Epoch 15: val_loss improved from 1.44410 to 1.40143, saving model to model.h5
# 61/61 - 5s - loss: 1.4990 - accuracy: 0.4680 - val_loss: 1.4014 - val_accuracy: 0.5034 - lr: 0.0010 - 5s/epoch - 74ms/step
# Epoch 16/50
#
# Epoch 16: val_loss improved from 1.40143 to 1.39394, saving model to model.h5
# 61/61 - 3s - loss: 1.4839 - accuracy: 0.4732 - val_loss: 1.3939 - val_accuracy: 0.5180 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 1.39394
# 61/61 - 2s - loss: 1.5013 - accuracy: 0.4572 - val_loss: 1.3954 - val_accuracy: 0.5023 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 18/50
#
# Epoch 18: val_loss improved from 1.39394 to 1.38548, saving model to model.h5
# 61/61 - 3s - loss: 1.4372 - accuracy: 0.4854 - val_loss: 1.3855 - val_accuracy: 0.5045 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 1.38548
# 61/61 - 2s - loss: 1.4652 - accuracy: 0.4733 - val_loss: 1.4332 - val_accuracy: 0.5124 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 20/50
#
# Epoch 20: val_loss improved from 1.38548 to 1.36554, saving model to model.h5
# 61/61 - 3s - loss: 1.4321 - accuracy: 0.4863 - val_loss: 1.3655 - val_accuracy: 0.5248 - lr: 0.0010 - 3s/epoch - 52ms/step
# Epoch 21/50
#
# Epoch 21: val_loss improved from 1.36554 to 1.35821, saving model to model.h5
# 61/61 - 3s - loss: 1.4216 - accuracy: 0.4908 - val_loss: 1.3582 - val_accuracy: 0.5124 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 1.35821
# 61/61 - 2s - loss: 1.4007 - accuracy: 0.5076 - val_loss: 1.3675 - val_accuracy: 0.5135 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 23/50
#
# Epoch 23: val_loss did not improve from 1.35821
# 61/61 - 2s - loss: 1.3945 - accuracy: 0.5041 - val_loss: 1.3893 - val_accuracy: 0.5158 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 24/50
#
# Epoch 24: val_loss improved from 1.35821 to 1.35552, saving model to model.h5
# 61/61 - 3s - loss: 1.4090 - accuracy: 0.5041 - val_loss: 1.3555 - val_accuracy: 0.5383 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 25/50
#
# Epoch 25: val_loss improved from 1.35552 to 1.35340, saving model to model.h5
# 61/61 - 3s - loss: 1.3639 - accuracy: 0.5137 - val_loss: 1.3534 - val_accuracy: 0.5225 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 1.35340
# 61/61 - 2s - loss: 1.3858 - accuracy: 0.5141 - val_loss: 1.3824 - val_accuracy: 0.5248 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 1.35340
# 61/61 - 2s - loss: 1.3586 - accuracy: 0.5203 - val_loss: 1.3545 - val_accuracy: 0.5360 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 1.35340
# 61/61 - 2s - loss: 1.3599 - accuracy: 0.5220 - val_loss: 1.3971 - val_accuracy: 0.5203 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 29/50
#
# Epoch 29: val_loss improved from 1.35340 to 1.35259, saving model to model.h5
# 61/61 - 3s - loss: 1.3654 - accuracy: 0.5172 - val_loss: 1.3526 - val_accuracy: 0.5394 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 1.35259
# 61/61 - 2s - loss: 1.3290 - accuracy: 0.5318 - val_loss: 1.3698 - val_accuracy: 0.5304 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 1.35259
# 61/61 - 2s - loss: 1.3263 - accuracy: 0.5302 - val_loss: 1.3560 - val_accuracy: 0.5293 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 32/50
#
# Epoch 32: val_loss improved from 1.35259 to 1.35213, saving model to model.h5
# 61/61 - 3s - loss: 1.2974 - accuracy: 0.5446 - val_loss: 1.3521 - val_accuracy: 0.5214 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 33/50
#
# Epoch 33: val_loss improved from 1.35213 to 1.34098, saving model to model.h5
# 61/61 - 4s - loss: 1.3327 - accuracy: 0.5351 - val_loss: 1.3410 - val_accuracy: 0.5101 - lr: 0.0010 - 4s/epoch - 59ms/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 1.34098
# 61/61 - 2s - loss: 1.2962 - accuracy: 0.5363 - val_loss: 1.3659 - val_accuracy: 0.5259 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 35/50
#
# Epoch 35: val_loss improved from 1.34098 to 1.33594, saving model to model.h5
# 61/61 - 3s - loss: 1.3113 - accuracy: 0.5399 - val_loss: 1.3359 - val_accuracy: 0.5518 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 1.33594
# 61/61 - 2s - loss: 1.3102 - accuracy: 0.5464 - val_loss: 1.3639 - val_accuracy: 0.5259 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 1.33594
# 61/61 - 2s - loss: 1.2696 - accuracy: 0.5468 - val_loss: 1.3810 - val_accuracy: 0.5169 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 38/50
#
# Epoch 38: val_loss improved from 1.33594 to 1.32670, saving model to model.h5
# 61/61 - 3s - loss: 1.2706 - accuracy: 0.5592 - val_loss: 1.3267 - val_accuracy: 0.5541 - lr: 0.0010 - 3s/epoch - 55ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 1.32670
# 61/61 - 2s - loss: 1.2675 - accuracy: 0.5557 - val_loss: 1.3728 - val_accuracy: 0.5169 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 1.32670
# 61/61 - 2s - loss: 1.2764 - accuracy: 0.5561 - val_loss: 1.3536 - val_accuracy: 0.5439 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 41/50
#
# Epoch 41: val_loss improved from 1.32670 to 1.32365, saving model to model.h5
# 61/61 - 3s - loss: 1.2599 - accuracy: 0.5550 - val_loss: 1.3237 - val_accuracy: 0.5439 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 1.32365
# 61/61 - 2s - loss: 1.2537 - accuracy: 0.5631 - val_loss: 1.3430 - val_accuracy: 0.5405 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 43/50
#
# Epoch 43: val_loss improved from 1.32365 to 1.31484, saving model to model.h5
# 61/61 - 3s - loss: 1.2375 - accuracy: 0.5590 - val_loss: 1.3148 - val_accuracy: 0.5428 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 1.31484
# 61/61 - 2s - loss: 1.2483 - accuracy: 0.5594 - val_loss: 1.3623 - val_accuracy: 0.5090 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 1.31484
# 61/61 - 2s - loss: 1.2334 - accuracy: 0.5658 - val_loss: 1.3559 - val_accuracy: 0.5191 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 1.31484
# 61/61 - 2s - loss: 1.2449 - accuracy: 0.5614 - val_loss: 1.3471 - val_accuracy: 0.5304 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 1.31484
# 61/61 - 2s - loss: 1.2041 - accuracy: 0.5788 - val_loss: 1.3382 - val_accuracy: 0.5428 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 1.31484
# 61/61 - 2s - loss: 1.2233 - accuracy: 0.5708 - val_loss: 1.3737 - val_accuracy: 0.5124 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 1.31484
# 61/61 - 2s - loss: 1.2174 - accuracy: 0.5735 - val_loss: 1.3282 - val_accuracy: 0.5315 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 1.31484
# 61/61 - 2s - loss: 1.2028 - accuracy: 0.5791 - val_loss: 1.4344 - val_accuracy: 0.5214 - lr: 0.0010 - 2s/epoch - 38ms/step
# 28/28 [==============================] - 1s 25ms/step - loss: 1.4344 - accuracy: 0.5214
# Validation accuracy: 0.5213963985443115
# 28/28 [==============================] - 4s 26ms/step
#  20%|██        | 2/10 [05:23<21:38, 162.35s/it]
# Training using fold3 as validation
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 2.66029, saving model to model.h5
# 60/60 - 14s - loss: 3.0504 - accuracy: 0.1475 - val_loss: 2.6603 - val_accuracy: 0.2886 - lr: 0.0010 - 14s/epoch - 227ms/step
# Epoch 2/50
#
# Epoch 2: val_loss improved from 2.66029 to 1.93913, saving model to model.h5
# 60/60 - 3s - loss: 2.5353 - accuracy: 0.1943 - val_loss: 1.9391 - val_accuracy: 0.3416 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 3/50
#
# Epoch 3: val_loss improved from 1.93913 to 1.82612, saving model to model.h5
# 60/60 - 3s - loss: 2.2371 - accuracy: 0.2412 - val_loss: 1.8261 - val_accuracy: 0.3362 - lr: 0.0010 - 3s/epoch - 58ms/step
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 1.82612
# 60/60 - 2s - loss: 2.0100 - accuracy: 0.3023 - val_loss: 1.8443 - val_accuracy: 0.3232 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 5/50
#
# Epoch 5: val_loss improved from 1.82612 to 1.79879, saving model to model.h5
# 60/60 - 3s - loss: 1.8675 - accuracy: 0.3364 - val_loss: 1.7988 - val_accuracy: 0.3470 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 6/50
#
# Epoch 6: val_loss improved from 1.79879 to 1.77188, saving model to model.h5
# 60/60 - 3s - loss: 1.8111 - accuracy: 0.3550 - val_loss: 1.7719 - val_accuracy: 0.3708 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 7/50
#
# Epoch 7: val_loss improved from 1.77188 to 1.72586, saving model to model.h5
# 60/60 - 3s - loss: 1.7080 - accuracy: 0.3902 - val_loss: 1.7259 - val_accuracy: 0.3654 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 8/50
#
# Epoch 8: val_loss improved from 1.72586 to 1.66269, saving model to model.h5
# 60/60 - 3s - loss: 1.6962 - accuracy: 0.3925 - val_loss: 1.6627 - val_accuracy: 0.3870 - lr: 0.0010 - 3s/epoch - 56ms/step
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 1.66269
# 60/60 - 3s - loss: 1.6566 - accuracy: 0.4106 - val_loss: 1.7198 - val_accuracy: 0.3708 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 1.66269
# 60/60 - 2s - loss: 1.6146 - accuracy: 0.4226 - val_loss: 1.7286 - val_accuracy: 0.3665 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 1.66269
# 60/60 - 2s - loss: 1.6237 - accuracy: 0.4191 - val_loss: 1.6803 - val_accuracy: 0.3827 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 1.66269
# 60/60 - 2s - loss: 1.5657 - accuracy: 0.4357 - val_loss: 1.6836 - val_accuracy: 0.4227 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 1.66269
# 60/60 - 2s - loss: 1.5176 - accuracy: 0.4563 - val_loss: 1.7007 - val_accuracy: 0.3870 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 14/50
#
# Epoch 14: val_loss improved from 1.66269 to 1.65476, saving model to model.h5
# 60/60 - 3s - loss: 1.5110 - accuracy: 0.4532 - val_loss: 1.6548 - val_accuracy: 0.3978 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 15/50
#
# Epoch 15: val_loss improved from 1.65476 to 1.63770, saving model to model.h5
# 60/60 - 3s - loss: 1.5023 - accuracy: 0.4624 - val_loss: 1.6377 - val_accuracy: 0.4108 - lr: 0.0010 - 3s/epoch - 58ms/step
# Epoch 16/50
#
# Epoch 16: val_loss improved from 1.63770 to 1.59663, saving model to model.h5
# 60/60 - 3s - loss: 1.4717 - accuracy: 0.4768 - val_loss: 1.5966 - val_accuracy: 0.4249 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 17/50
#
# Epoch 17: val_loss improved from 1.59663 to 1.59060, saving model to model.h5
# 60/60 - 3s - loss: 1.4709 - accuracy: 0.4751 - val_loss: 1.5906 - val_accuracy: 0.4411 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 1.59060
# 60/60 - 2s - loss: 1.4517 - accuracy: 0.4769 - val_loss: 1.6296 - val_accuracy: 0.4314 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 1.59060
# 60/60 - 2s - loss: 1.4379 - accuracy: 0.4824 - val_loss: 1.6160 - val_accuracy: 0.4411 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 1.59060
# 60/60 - 3s - loss: 1.4249 - accuracy: 0.4891 - val_loss: 1.6275 - val_accuracy: 0.4184 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 1.59060
# 60/60 - 2s - loss: 1.4087 - accuracy: 0.4915 - val_loss: 1.6056 - val_accuracy: 0.4443 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 22/50
#
# Epoch 22: val_loss improved from 1.59060 to 1.58135, saving model to model.h5
# 60/60 - 3s - loss: 1.3967 - accuracy: 0.4999 - val_loss: 1.5813 - val_accuracy: 0.4551 - lr: 0.0010 - 3s/epoch - 52ms/step
# Epoch 23/50
#
# Epoch 23: val_loss improved from 1.58135 to 1.57556, saving model to model.h5
# 60/60 - 3s - loss: 1.3548 - accuracy: 0.5141 - val_loss: 1.5756 - val_accuracy: 0.4389 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 24/50
#
# Epoch 24: val_loss improved from 1.57556 to 1.57554, saving model to model.h5
# 60/60 - 3s - loss: 1.3888 - accuracy: 0.5123 - val_loss: 1.5755 - val_accuracy: 0.4573 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 1.57554
# 60/60 - 2s - loss: 1.3607 - accuracy: 0.5139 - val_loss: 1.5930 - val_accuracy: 0.4411 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 26/50
#
# Epoch 26: val_loss improved from 1.57554 to 1.57054, saving model to model.h5
# 60/60 - 3s - loss: 1.3392 - accuracy: 0.5234 - val_loss: 1.5705 - val_accuracy: 0.4670 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 27/50
#
# Epoch 27: val_loss improved from 1.57054 to 1.56534, saving model to model.h5
# 60/60 - 3s - loss: 1.3634 - accuracy: 0.5124 - val_loss: 1.5653 - val_accuracy: 0.4476 - lr: 0.0010 - 3s/epoch - 51ms/step
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 1.56534
# 60/60 - 2s - loss: 1.3389 - accuracy: 0.5301 - val_loss: 1.5977 - val_accuracy: 0.4303 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 29/50
#
# Epoch 29: val_loss improved from 1.56534 to 1.53013, saving model to model.h5
# 60/60 - 3s - loss: 1.3203 - accuracy: 0.5290 - val_loss: 1.5301 - val_accuracy: 0.4627 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 1.53013
# 60/60 - 2s - loss: 1.3328 - accuracy: 0.5287 - val_loss: 1.5568 - val_accuracy: 0.4649 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 1.53013
# 60/60 - 2s - loss: 1.3308 - accuracy: 0.5283 - val_loss: 1.5359 - val_accuracy: 0.4530 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 1.53013
# 60/60 - 3s - loss: 1.2996 - accuracy: 0.5468 - val_loss: 1.5631 - val_accuracy: 0.4454 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 1.53013
# 60/60 - 2s - loss: 1.2987 - accuracy: 0.5442 - val_loss: 1.5419 - val_accuracy: 0.4497 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 34/50
#
# Epoch 34: val_loss improved from 1.53013 to 1.52459, saving model to model.h5
# 60/60 - 3s - loss: 1.2969 - accuracy: 0.5502 - val_loss: 1.5246 - val_accuracy: 0.4703 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 1.52459
# 60/60 - 2s - loss: 1.2863 - accuracy: 0.5449 - val_loss: 1.5764 - val_accuracy: 0.4519 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 1.52459
# 60/60 - 2s - loss: 1.2629 - accuracy: 0.5558 - val_loss: 1.5380 - val_accuracy: 0.4584 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 37/50
#
# Epoch 37: val_loss improved from 1.52459 to 1.48950, saving model to model.h5
# 60/60 - 3s - loss: 1.2716 - accuracy: 0.5555 - val_loss: 1.4895 - val_accuracy: 0.4757 - lr: 0.0010 - 3s/epoch - 53ms/step
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 1.48950
# 60/60 - 3s - loss: 1.2494 - accuracy: 0.5611 - val_loss: 1.5391 - val_accuracy: 0.4659 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 1.48950
# 60/60 - 2s - loss: 1.2606 - accuracy: 0.5538 - val_loss: 1.5273 - val_accuracy: 0.4595 - lr: 0.0010 - 2s/epoch - 42ms/step
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 1.48950
# 60/60 - 2s - loss: 1.2637 - accuracy: 0.5567 - val_loss: 1.5378 - val_accuracy: 0.4530 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 1.48950
# 60/60 - 2s - loss: 1.2184 - accuracy: 0.5743 - val_loss: 1.5182 - val_accuracy: 0.4562 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 1.48950
# 60/60 - 2s - loss: 1.2381 - accuracy: 0.5708 - val_loss: 1.5073 - val_accuracy: 0.4551 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 1.48950
# 60/60 - 2s - loss: 1.2374 - accuracy: 0.5704 - val_loss: 1.5072 - val_accuracy: 0.4649 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 1.48950
# 60/60 - 2s - loss: 1.2021 - accuracy: 0.5716 - val_loss: 1.4941 - val_accuracy: 0.4865 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 1.48950
# 60/60 - 3s - loss: 1.2130 - accuracy: 0.5790 - val_loss: 1.5087 - val_accuracy: 0.4638 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 1.48950
# 60/60 - 2s - loss: 1.2112 - accuracy: 0.5791 - val_loss: 1.5102 - val_accuracy: 0.4778 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 1.48950
# 60/60 - 2s - loss: 1.2011 - accuracy: 0.5800 - val_loss: 1.5191 - val_accuracy: 0.4735 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 48/50
#
# Epoch 48: val_loss improved from 1.48950 to 1.48697, saving model to model.h5
# 60/60 - 3s - loss: 1.2074 - accuracy: 0.5830 - val_loss: 1.4870 - val_accuracy: 0.4811 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 1.48697
# 60/60 - 2s - loss: 1.1903 - accuracy: 0.5887 - val_loss: 1.5271 - val_accuracy: 0.4627 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 1.48697
# 60/60 - 2s - loss: 1.2004 - accuracy: 0.5835 - val_loss: 1.5109 - val_accuracy: 0.4649 - lr: 0.0010 - 2s/epoch - 38ms/step
# 29/29 [==============================] - 1s 24ms/step - loss: 1.5109 - accuracy: 0.4649
# Validation accuracy: 0.4648648500442505
# 29/29 [==============================] - 2s 20ms/step
#  30%|███       | 3/10 [08:06<18:58, 162.67s/it]
# Training using fold4 as validation
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 2.67543, saving model to model.h5
# 60/60 - 14s - loss: 3.1165 - accuracy: 0.1417 - val_loss: 2.6754 - val_accuracy: 0.2253 - lr: 0.0010 - 14s/epoch - 236ms/step
# Epoch 2/50
#
# Epoch 2: val_loss improved from 2.67543 to 2.00916, saving model to model.h5
# 60/60 - 3s - loss: 2.4900 - accuracy: 0.2112 - val_loss: 2.0092 - val_accuracy: 0.2677 - lr: 0.0010 - 3s/epoch - 53ms/step
# Epoch 3/50
#
# Epoch 3: val_loss improved from 2.00916 to 1.87974, saving model to model.h5
# 60/60 - 3s - loss: 2.1964 - accuracy: 0.2696 - val_loss: 1.8797 - val_accuracy: 0.3071 - lr: 0.0010 - 3s/epoch - 58ms/step
# Epoch 4/50
#
# Epoch 4: val_loss improved from 1.87974 to 1.82220, saving model to model.h5
# 60/60 - 4s - loss: 2.0144 - accuracy: 0.3093 - val_loss: 1.8222 - val_accuracy: 0.3212 - lr: 0.0010 - 4s/epoch - 59ms/step
# Epoch 5/50
#
# Epoch 5: val_loss did not improve from 1.82220
# 60/60 - 2s - loss: 1.8859 - accuracy: 0.3356 - val_loss: 1.8879 - val_accuracy: 0.3323 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 6/50
#
# Epoch 6: val_loss improved from 1.82220 to 1.74428, saving model to model.h5
# 60/60 - 3s - loss: 1.7847 - accuracy: 0.3693 - val_loss: 1.7443 - val_accuracy: 0.3818 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 1.74428
# 60/60 - 2s - loss: 1.7266 - accuracy: 0.3885 - val_loss: 1.7923 - val_accuracy: 0.3576 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 8/50
#
# Epoch 8: val_loss improved from 1.74428 to 1.67076, saving model to model.h5
# 60/60 - 3s - loss: 1.6521 - accuracy: 0.4094 - val_loss: 1.6708 - val_accuracy: 0.4000 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 1.67076
# 60/60 - 2s - loss: 1.6343 - accuracy: 0.4212 - val_loss: 1.7247 - val_accuracy: 0.3636 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 1.67076
# 60/60 - 2s - loss: 1.5989 - accuracy: 0.4262 - val_loss: 1.6875 - val_accuracy: 0.3636 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 11/50
#
# Epoch 11: val_loss improved from 1.67076 to 1.61553, saving model to model.h5
# 60/60 - 3s - loss: 1.5565 - accuracy: 0.4392 - val_loss: 1.6155 - val_accuracy: 0.4111 - lr: 0.0010 - 3s/epoch - 56ms/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 1.61553
# 60/60 - 2s - loss: 1.5473 - accuracy: 0.4443 - val_loss: 1.6733 - val_accuracy: 0.3869 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 1.61553
# 60/60 - 2s - loss: 1.5227 - accuracy: 0.4577 - val_loss: 1.6248 - val_accuracy: 0.3939 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 14/50
#
# Epoch 14: val_loss did not improve from 1.61553
# 60/60 - 2s - loss: 1.5080 - accuracy: 0.4601 - val_loss: 1.6365 - val_accuracy: 0.4051 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 15/50
#
# Epoch 15: val_loss did not improve from 1.61553
# 60/60 - 2s - loss: 1.4776 - accuracy: 0.4754 - val_loss: 1.6399 - val_accuracy: 0.3798 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 1.61553
# 60/60 - 2s - loss: 1.4639 - accuracy: 0.4789 - val_loss: 1.6303 - val_accuracy: 0.3838 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 17/50
#
# Epoch 17: val_loss improved from 1.61553 to 1.60728, saving model to model.h5
# 60/60 - 3s - loss: 1.4282 - accuracy: 0.4840 - val_loss: 1.6073 - val_accuracy: 0.4000 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 18/50
#
# Epoch 18: val_loss improved from 1.60728 to 1.59856, saving model to model.h5
# 60/60 - 3s - loss: 1.4495 - accuracy: 0.4870 - val_loss: 1.5986 - val_accuracy: 0.3919 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 19/50
#
# Epoch 19: val_loss improved from 1.59856 to 1.58650, saving model to model.h5
# 60/60 - 3s - loss: 1.4298 - accuracy: 0.4923 - val_loss: 1.5865 - val_accuracy: 0.3980 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 20/50
#
# Epoch 20: val_loss improved from 1.58650 to 1.57480, saving model to model.h5
# 60/60 - 3s - loss: 1.3987 - accuracy: 0.5089 - val_loss: 1.5748 - val_accuracy: 0.4121 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 21/50
#
# Epoch 21: val_loss improved from 1.57480 to 1.57475, saving model to model.h5
# 60/60 - 3s - loss: 1.3989 - accuracy: 0.5079 - val_loss: 1.5748 - val_accuracy: 0.4242 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 22/50
#
# Epoch 22: val_loss improved from 1.57475 to 1.55060, saving model to model.h5
# 60/60 - 3s - loss: 1.3815 - accuracy: 0.5122 - val_loss: 1.5506 - val_accuracy: 0.4303 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 23/50
#
# Epoch 23: val_loss improved from 1.55060 to 1.53503, saving model to model.h5
# 60/60 - 3s - loss: 1.3599 - accuracy: 0.5239 - val_loss: 1.5350 - val_accuracy: 0.4434 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 1.53503
# 60/60 - 2s - loss: 1.3631 - accuracy: 0.5194 - val_loss: 1.5778 - val_accuracy: 0.4323 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 1.53503
# 60/60 - 2s - loss: 1.3577 - accuracy: 0.5242 - val_loss: 1.6128 - val_accuracy: 0.4182 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 1.53503
# 60/60 - 2s - loss: 1.3436 - accuracy: 0.5209 - val_loss: 1.5677 - val_accuracy: 0.4303 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 1.53503
# 60/60 - 2s - loss: 1.3209 - accuracy: 0.5397 - val_loss: 1.5521 - val_accuracy: 0.4273 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 1.53503
# 60/60 - 2s - loss: 1.3298 - accuracy: 0.5301 - val_loss: 1.5544 - val_accuracy: 0.4172 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 1.53503
# 60/60 - 2s - loss: 1.3154 - accuracy: 0.5419 - val_loss: 1.5584 - val_accuracy: 0.4242 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 1.53503
# 60/60 - 2s - loss: 1.3048 - accuracy: 0.5408 - val_loss: 1.5738 - val_accuracy: 0.4192 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 31/50
#
# Epoch 31: val_loss improved from 1.53503 to 1.52510, saving model to model.h5
# 60/60 - 3s - loss: 1.2827 - accuracy: 0.5503 - val_loss: 1.5251 - val_accuracy: 0.4596 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 1.52510
# 60/60 - 2s - loss: 1.2953 - accuracy: 0.5456 - val_loss: 1.5329 - val_accuracy: 0.4495 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 33/50
#
# Epoch 33: val_loss improved from 1.52510 to 1.51490, saving model to model.h5
# 60/60 - 3s - loss: 1.2909 - accuracy: 0.5440 - val_loss: 1.5149 - val_accuracy: 0.4465 - lr: 0.0010 - 3s/epoch - 53ms/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 1.51490
# 60/60 - 2s - loss: 1.2425 - accuracy: 0.5596 - val_loss: 1.5490 - val_accuracy: 0.4121 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 35/50
#
# Epoch 35: val_loss improved from 1.51490 to 1.47794, saving model to model.h5
# 60/60 - 3s - loss: 1.2785 - accuracy: 0.5552 - val_loss: 1.4779 - val_accuracy: 0.4697 - lr: 0.0010 - 3s/epoch - 56ms/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 1.47794
# 60/60 - 3s - loss: 1.2503 - accuracy: 0.5600 - val_loss: 1.5287 - val_accuracy: 0.4384 - lr: 0.0010 - 3s/epoch - 45ms/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.2657 - accuracy: 0.5566 - val_loss: 1.5055 - val_accuracy: 0.4596 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.2209 - accuracy: 0.5801 - val_loss: 1.5462 - val_accuracy: 0.4414 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.2291 - accuracy: 0.5665 - val_loss: 1.5837 - val_accuracy: 0.4232 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.2477 - accuracy: 0.5725 - val_loss: 1.5609 - val_accuracy: 0.4273 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.2158 - accuracy: 0.5724 - val_loss: 1.5469 - val_accuracy: 0.4354 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.2169 - accuracy: 0.5735 - val_loss: 1.5577 - val_accuracy: 0.4232 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.2193 - accuracy: 0.5755 - val_loss: 1.5501 - val_accuracy: 0.4404 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.2148 - accuracy: 0.5686 - val_loss: 1.5493 - val_accuracy: 0.4323 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.2154 - accuracy: 0.5831 - val_loss: 1.5173 - val_accuracy: 0.4576 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.1961 - accuracy: 0.5881 - val_loss: 1.5211 - val_accuracy: 0.4475 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 1.47794
# 60/60 - 3s - loss: 1.1989 - accuracy: 0.5866 - val_loss: 1.5372 - val_accuracy: 0.4444 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.1870 - accuracy: 0.5808 - val_loss: 1.5304 - val_accuracy: 0.4444 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.1706 - accuracy: 0.5864 - val_loss: 1.5252 - val_accuracy: 0.4535 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 1.47794
# 60/60 - 2s - loss: 1.1785 - accuracy: 0.5939 - val_loss: 1.5566 - val_accuracy: 0.4323 - lr: 0.0010 - 2s/epoch - 36ms/step
# 31/31 [==============================] - 1s 26ms/step - loss: 1.5566 - accuracy: 0.4323
# Validation accuracy: 0.43232324719429016
# 31/31 [==============================] - 3s 20ms/step
#  40%|████      | 4/10 [10:51<16:22, 163.73s/it]
# Training using fold5 as validation
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 2.73851, saving model to model.h5
# 60/60 - 15s - loss: 3.0680 - accuracy: 0.1444 - val_loss: 2.7385 - val_accuracy: 0.2158 - lr: 0.0010 - 15s/epoch - 249ms/step
# Epoch 2/50
#
# Epoch 2: val_loss improved from 2.73851 to 2.17068, saving model to model.h5
# 60/60 - 3s - loss: 2.5378 - accuracy: 0.1948 - val_loss: 2.1707 - val_accuracy: 0.1934 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 3/50
#
# Epoch 3: val_loss improved from 2.17068 to 1.82899, saving model to model.h5
# 60/60 - 3s - loss: 2.2747 - accuracy: 0.2251 - val_loss: 1.8290 - val_accuracy: 0.3558 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 4/50
#
# Epoch 4: val_loss improved from 1.82899 to 1.78644, saving model to model.h5
# 60/60 - 3s - loss: 2.0761 - accuracy: 0.2703 - val_loss: 1.7864 - val_accuracy: 0.3803 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 5/50
#
# Epoch 5: val_loss improved from 1.78644 to 1.69656, saving model to model.h5
# 60/60 - 3s - loss: 1.9622 - accuracy: 0.2990 - val_loss: 1.6966 - val_accuracy: 0.4038 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 6/50
#
# Epoch 6: val_loss improved from 1.69656 to 1.65597, saving model to model.h5
# 60/60 - 4s - loss: 1.8488 - accuracy: 0.3438 - val_loss: 1.6560 - val_accuracy: 0.4263 - lr: 0.0010 - 4s/epoch - 59ms/step
# Epoch 7/50
#
# Epoch 7: val_loss improved from 1.65597 to 1.58200, saving model to model.h5
# 60/60 - 3s - loss: 1.7487 - accuracy: 0.3753 - val_loss: 1.5820 - val_accuracy: 0.4391 - lr: 0.0010 - 3s/epoch - 52ms/step
# Epoch 8/50
#
# Epoch 8: val_loss improved from 1.58200 to 1.54974, saving model to model.h5
# 60/60 - 3s - loss: 1.7111 - accuracy: 0.3847 - val_loss: 1.5497 - val_accuracy: 0.4669 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 9/50
#
# Epoch 9: val_loss improved from 1.54974 to 1.53189, saving model to model.h5
# 60/60 - 3s - loss: 1.6553 - accuracy: 0.4066 - val_loss: 1.5319 - val_accuracy: 0.4583 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 10/50
#
# Epoch 10: val_loss improved from 1.53189 to 1.52600, saving model to model.h5
# 60/60 - 3s - loss: 1.6556 - accuracy: 0.4014 - val_loss: 1.5260 - val_accuracy: 0.4701 - lr: 0.0010 - 3s/epoch - 53ms/step
# Epoch 11/50
#
# Epoch 11: val_loss improved from 1.52600 to 1.49245, saving model to model.h5
# 60/60 - 3s - loss: 1.6007 - accuracy: 0.4259 - val_loss: 1.4924 - val_accuracy: 0.4583 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 12/50
#
# Epoch 12: val_loss improved from 1.49245 to 1.48816, saving model to model.h5
# 60/60 - 3s - loss: 1.5758 - accuracy: 0.4397 - val_loss: 1.4882 - val_accuracy: 0.4583 - lr: 0.0010 - 3s/epoch - 51ms/step
# Epoch 13/50
#
# Epoch 13: val_loss improved from 1.48816 to 1.44801, saving model to model.h5
# 60/60 - 3s - loss: 1.5788 - accuracy: 0.4334 - val_loss: 1.4480 - val_accuracy: 0.4818 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 14/50
#
# Epoch 14: val_loss improved from 1.44801 to 1.42779, saving model to model.h5
# 60/60 - 3s - loss: 1.5395 - accuracy: 0.4472 - val_loss: 1.4278 - val_accuracy: 0.4861 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 15/50
#
# Epoch 15: val_loss did not improve from 1.42779
# 60/60 - 2s - loss: 1.5444 - accuracy: 0.4495 - val_loss: 1.4345 - val_accuracy: 0.4744 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 1.42779
# 60/60 - 2s - loss: 1.5038 - accuracy: 0.4661 - val_loss: 1.4572 - val_accuracy: 0.4850 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 1.42779
# 60/60 - 2s - loss: 1.4712 - accuracy: 0.4725 - val_loss: 1.4616 - val_accuracy: 0.4647 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 1.42779
# 60/60 - 2s - loss: 1.4706 - accuracy: 0.4760 - val_loss: 1.4758 - val_accuracy: 0.4626 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 1.42779
# 60/60 - 2s - loss: 1.4605 - accuracy: 0.4816 - val_loss: 1.4336 - val_accuracy: 0.4808 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 1.42779
# 60/60 - 2s - loss: 1.4356 - accuracy: 0.4909 - val_loss: 1.4380 - val_accuracy: 0.4850 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 21/50
#
# Epoch 21: val_loss improved from 1.42779 to 1.42481, saving model to model.h5
# 60/60 - 3s - loss: 1.4284 - accuracy: 0.5003 - val_loss: 1.4248 - val_accuracy: 0.4968 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 1.42481
# 60/60 - 2s - loss: 1.4231 - accuracy: 0.4970 - val_loss: 1.4935 - val_accuracy: 0.4615 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 23/50
#
# Epoch 23: val_loss did not improve from 1.42481
# 60/60 - 3s - loss: 1.3963 - accuracy: 0.5064 - val_loss: 1.4323 - val_accuracy: 0.4872 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 1.42481
# 60/60 - 2s - loss: 1.3918 - accuracy: 0.5134 - val_loss: 1.4646 - val_accuracy: 0.4605 - lr: 0.0010 - 2s/epoch - 39ms/step
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 1.42481
# 60/60 - 2s - loss: 1.3800 - accuracy: 0.5164 - val_loss: 1.4485 - val_accuracy: 0.4733 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 1.42481
# 60/60 - 2s - loss: 1.3644 - accuracy: 0.5117 - val_loss: 1.4778 - val_accuracy: 0.4872 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 27/50
#
# Epoch 27: val_loss improved from 1.42481 to 1.40803, saving model to model.h5
# 60/60 - 3s - loss: 1.3621 - accuracy: 0.5198 - val_loss: 1.4080 - val_accuracy: 0.4989 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 28/50
#
# Epoch 28: val_loss improved from 1.40803 to 1.39742, saving model to model.h5
# 60/60 - 3s - loss: 1.3669 - accuracy: 0.5188 - val_loss: 1.3974 - val_accuracy: 0.4989 - lr: 0.0010 - 3s/epoch - 55ms/step
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 1.39742
# 60/60 - 3s - loss: 1.3434 - accuracy: 0.5248 - val_loss: 1.4084 - val_accuracy: 0.4936 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 1.39742
# 60/60 - 2s - loss: 1.3319 - accuracy: 0.5290 - val_loss: 1.4261 - val_accuracy: 0.4808 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 1.39742
# 60/60 - 2s - loss: 1.3322 - accuracy: 0.5363 - val_loss: 1.4331 - val_accuracy: 0.4776 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 1.39742
# 60/60 - 2s - loss: 1.3113 - accuracy: 0.5374 - val_loss: 1.4593 - val_accuracy: 0.4776 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 1.39742
# 60/60 - 2s - loss: 1.3248 - accuracy: 0.5317 - val_loss: 1.4458 - val_accuracy: 0.4979 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 1.39742
# 60/60 - 2s - loss: 1.3127 - accuracy: 0.5386 - val_loss: 1.4070 - val_accuracy: 0.5064 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 35/50
#
# Epoch 35: val_loss improved from 1.39742 to 1.38385, saving model to model.h5
# 60/60 - 4s - loss: 1.2933 - accuracy: 0.5466 - val_loss: 1.3839 - val_accuracy: 0.5000 - lr: 0.0010 - 4s/epoch - 59ms/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 1.38385
# 60/60 - 3s - loss: 1.2983 - accuracy: 0.5417 - val_loss: 1.3945 - val_accuracy: 0.5000 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 1.38385
# 60/60 - 2s - loss: 1.2877 - accuracy: 0.5432 - val_loss: 1.4259 - val_accuracy: 0.5000 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 1.38385
# 60/60 - 2s - loss: 1.2966 - accuracy: 0.5445 - val_loss: 1.4370 - val_accuracy: 0.5064 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 1.38385
# ...
# 61/61 - 3s - loss: 1.4411 - accuracy: 0.4839 - val_loss: 1.2280 - val_accuracy: 0.5588 - lr: 0.0010 - 3s/epoch - 48ms/step
# Epoch 25/50
#
# Epoch 25: val_loss improved from 1.22802 to 1.21124, saving model to model.h5
# 61/61 - 3s - loss: 1.4413 - accuracy: 0.4923 - val_loss: 1.2112 - val_accuracy: 0.5417 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 1.21124
# 61/61 - 2s - loss: 1.4104 - accuracy: 0.5005 - val_loss: 1.2139 - val_accuracy: 0.5588 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 27/50
#
# Epoch 27: val_loss improved from 1.21124 to 1.20272, saving model to model.h5
# 61/61 - 3s - loss: 1.3847 - accuracy: 0.5040 - val_loss: 1.2027 - val_accuracy: 0.5515 - lr: 0.0010 - 3s/epoch - 56ms/step
# Epoch 28/50
#
# Epoch 28: val_loss improved from 1.20272 to 1.19434, saving model to model.h5
# 61/61 - 3s - loss: 1.4034 - accuracy: 0.5083 - val_loss: 1.1943 - val_accuracy: 0.5760 - lr: 0.0010 - 3s/epoch - 53ms/step
# Epoch 29/50
#
# Epoch 29: val_loss improved from 1.19434 to 1.19410, saving model to model.h5
# 61/61 - 3s - loss: 1.3664 - accuracy: 0.5189 - val_loss: 1.1941 - val_accuracy: 0.5821 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 30/50
#
# Epoch 30: val_loss improved from 1.19410 to 1.17589, saving model to model.h5
# 61/61 - 3s - loss: 1.3784 - accuracy: 0.5127 - val_loss: 1.1759 - val_accuracy: 0.5527 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 31/50
#
# Epoch 31: val_loss improved from 1.17589 to 1.16590, saving model to model.h5
# 61/61 - 3s - loss: 1.3621 - accuracy: 0.5199 - val_loss: 1.1659 - val_accuracy: 0.5895 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 32/50
#
# Epoch 32: val_loss improved from 1.16590 to 1.16497, saving model to model.h5
# 61/61 - 3s - loss: 1.3476 - accuracy: 0.5284 - val_loss: 1.1650 - val_accuracy: 0.6029 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 33/50
#
# Epoch 33: val_loss improved from 1.16497 to 1.14820, saving model to model.h5
# 61/61 - 3s - loss: 1.3402 - accuracy: 0.5259 - val_loss: 1.1482 - val_accuracy: 0.5944 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 1.14820
# 61/61 - 2s - loss: 1.3394 - accuracy: 0.5282 - val_loss: 1.1706 - val_accuracy: 0.5723 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 1.14820
# 61/61 - 2s - loss: 1.3270 - accuracy: 0.5304 - val_loss: 1.1522 - val_accuracy: 0.5907 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 1.14820
# 61/61 - 2s - loss: 1.3136 - accuracy: 0.5353 - val_loss: 1.1653 - val_accuracy: 0.5821 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 1.14820
# 61/61 - 2s - loss: 1.3310 - accuracy: 0.5393 - val_loss: 1.1539 - val_accuracy: 0.5944 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 1.14820
# 61/61 - 3s - loss: 1.3055 - accuracy: 0.5406 - val_loss: 1.1736 - val_accuracy: 0.5833 - lr: 0.0010 - 3s/epoch - 41ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 1.14820
# 61/61 - 3s - loss: 1.3007 - accuracy: 0.5460 - val_loss: 1.1520 - val_accuracy: 0.5956 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 40/50
#
# Epoch 40: val_loss improved from 1.14820 to 1.14648, saving model to model.h5
# 61/61 - 3s - loss: 1.3116 - accuracy: 0.5404 - val_loss: 1.1465 - val_accuracy: 0.6103 - lr: 0.0010 - 3s/epoch - 51ms/step
# Epoch 41/50
#
# Epoch 41: val_loss improved from 1.14648 to 1.13684, saving model to model.h5
# 61/61 - 3s - loss: 1.2765 - accuracy: 0.5573 - val_loss: 1.1368 - val_accuracy: 0.6078 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 1.13684
# 61/61 - 2s - loss: 1.2840 - accuracy: 0.5499 - val_loss: 1.1486 - val_accuracy: 0.5919 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 43/50
#
# Epoch 43: val_loss improved from 1.13684 to 1.12973, saving model to model.h5
# 61/61 - 3s - loss: 1.2609 - accuracy: 0.5637 - val_loss: 1.1297 - val_accuracy: 0.6140 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 1.12973
# 61/61 - 3s - loss: 1.2636 - accuracy: 0.5566 - val_loss: 1.1310 - val_accuracy: 0.6127 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 1.12973
# 61/61 - 3s - loss: 1.2669 - accuracy: 0.5515 - val_loss: 1.1308 - val_accuracy: 0.6078 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 1.12973
# 61/61 - 2s - loss: 1.2808 - accuracy: 0.5498 - val_loss: 1.1465 - val_accuracy: 0.6164 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 47/50
#
# Epoch 47: val_loss improved from 1.12973 to 1.09764, saving model to model.h5
# 61/61 - 3s - loss: 1.2381 - accuracy: 0.5621 - val_loss: 1.0976 - val_accuracy: 0.6324 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 48/50
#
# Epoch 48: val_loss improved from 1.09764 to 1.09743, saving model to model.h5
# 61/61 - 3s - loss: 1.2419 - accuracy: 0.5648 - val_loss: 1.0974 - val_accuracy: 0.6201 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 1.09743
# 61/61 - 2s - loss: 1.2396 - accuracy: 0.5629 - val_loss: 1.1248 - val_accuracy: 0.6189 - lr: 0.0010 - 2s/epoch - 38ms/step
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 1.09743
# 61/61 - 3s - loss: 1.2450 - accuracy: 0.5588 - val_loss: 1.1080 - val_accuracy: 0.6176 - lr: 0.0010 - 3s/epoch - 43ms/step
# 26/26 [==============================] - 1s 25ms/step - loss: 1.1080 - accuracy: 0.6176
# Validation accuracy: 0.6176470518112183
# 26/26 [==============================] - 3s 22ms/step
#  90%|█████████ | 9/10 [24:22<02:43, 163.19s/it]
# Training using fold10 as validation
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 2.56912, saving model to model.h5
# 61/61 - 16s - loss: 3.1141 - accuracy: 0.1474 - val_loss: 2.5691 - val_accuracy: 0.2019 - lr: 0.0010 - 16s/epoch - 266ms/step
# Epoch 2/50
#
# Epoch 2: val_loss improved from 2.56912 to 1.99162, saving model to model.h5
# 61/61 - 3s - loss: 2.5719 - accuracy: 0.1952 - val_loss: 1.9916 - val_accuracy: 0.2652 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 3/50
#
# Epoch 3: val_loss improved from 1.99162 to 1.66502, saving model to model.h5
# 61/61 - 3s - loss: 2.2613 - accuracy: 0.2390 - val_loss: 1.6650 - val_accuracy: 0.4205 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 4/50
#
# Epoch 4: val_loss improved from 1.66502 to 1.61532, saving model to model.h5
# 61/61 - 3s - loss: 2.0707 - accuracy: 0.2835 - val_loss: 1.6153 - val_accuracy: 0.4421 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 5/50
#
# Epoch 5: val_loss did not improve from 1.61532
# 61/61 - 2s - loss: 1.9487 - accuracy: 0.3172 - val_loss: 1.6189 - val_accuracy: 0.4815 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 6/50
#
# Epoch 6: val_loss improved from 1.61532 to 1.58312, saving model to model.h5
# 61/61 - 3s - loss: 1.8536 - accuracy: 0.3386 - val_loss: 1.5831 - val_accuracy: 0.4421 - lr: 0.0010 - 3s/epoch - 54ms/step
# Epoch 7/50
#
# Epoch 7: val_loss improved from 1.58312 to 1.51431, saving model to model.h5
# 61/61 - 3s - loss: 1.7928 - accuracy: 0.3600 - val_loss: 1.5143 - val_accuracy: 0.4898 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 8/50
#
# Epoch 8: val_loss improved from 1.51431 to 1.48392, saving model to model.h5
# 61/61 - 3s - loss: 1.7269 - accuracy: 0.3891 - val_loss: 1.4839 - val_accuracy: 0.4779 - lr: 0.0010 - 3s/epoch - 50ms/step
# Epoch 9/50
#
# Epoch 9: val_loss improved from 1.48392 to 1.45336, saving model to model.h5
# 61/61 - 3s - loss: 1.6621 - accuracy: 0.4066 - val_loss: 1.4534 - val_accuracy: 0.5137 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 1.45336
# 61/61 - 2s - loss: 1.6316 - accuracy: 0.4223 - val_loss: 1.4809 - val_accuracy: 0.4910 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 1.45336
# 61/61 - 2s - loss: 1.5990 - accuracy: 0.4296 - val_loss: 1.4922 - val_accuracy: 0.4898 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 1.45336
# 61/61 - 3s - loss: 1.5738 - accuracy: 0.4287 - val_loss: 1.4775 - val_accuracy: 0.4671 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 1.45336
# 61/61 - 3s - loss: 1.5486 - accuracy: 0.4490 - val_loss: 1.4537 - val_accuracy: 0.4815 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 14/50
#
# Epoch 14: val_loss improved from 1.45336 to 1.43011, saving model to model.h5
# 61/61 - 3s - loss: 1.5228 - accuracy: 0.4520 - val_loss: 1.4301 - val_accuracy: 0.5018 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 15/50
#
# Epoch 15: val_loss improved from 1.43011 to 1.39216, saving model to model.h5
# 61/61 - 3s - loss: 1.5176 - accuracy: 0.4625 - val_loss: 1.3922 - val_accuracy: 0.5364 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 1.39216
# 61/61 - 2s - loss: 1.4862 - accuracy: 0.4717 - val_loss: 1.4596 - val_accuracy: 0.4910 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 1.39216
# 61/61 - 2s - loss: 1.4753 - accuracy: 0.4761 - val_loss: 1.3956 - val_accuracy: 0.5197 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 1.39216
# 61/61 - 3s - loss: 1.4532 - accuracy: 0.4845 - val_loss: 1.3996 - val_accuracy: 0.5197 - lr: 0.0010 - 3s/epoch - 41ms/step
# Epoch 19/50
#
# Epoch 19: val_loss improved from 1.39216 to 1.37861, saving model to model.h5
# 61/61 - 3s - loss: 1.4453 - accuracy: 0.4810 - val_loss: 1.3786 - val_accuracy: 0.5066 - lr: 0.0010 - 3s/epoch - 57ms/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 1.37861
# 61/61 - 2s - loss: 1.4493 - accuracy: 0.4868 - val_loss: 1.3845 - val_accuracy: 0.5556 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 1.37861
# 61/61 - 2s - loss: 1.4188 - accuracy: 0.4931 - val_loss: 1.3846 - val_accuracy: 0.5245 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 1.37861
# 61/61 - 2s - loss: 1.4048 - accuracy: 0.5033 - val_loss: 1.3797 - val_accuracy: 0.5102 - lr: 0.0010 - 2s/epoch - 35ms/step
# Epoch 23/50
#
# Epoch 23: val_loss did not improve from 1.37861
# 61/61 - 2s - loss: 1.4035 - accuracy: 0.5053 - val_loss: 1.4263 - val_accuracy: 0.4922 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 24/50
#
# Epoch 24: val_loss improved from 1.37861 to 1.37808, saving model to model.h5
# 61/61 - 3s - loss: 1.3769 - accuracy: 0.5142 - val_loss: 1.3781 - val_accuracy: 0.5054 - lr: 0.0010 - 3s/epoch - 55ms/step
# Epoch 25/50
#
# Epoch 25: val_loss improved from 1.37808 to 1.35355, saving model to model.h5
# 61/61 - 3s - loss: 1.3780 - accuracy: 0.5126 - val_loss: 1.3536 - val_accuracy: 0.5281 - lr: 0.0010 - 3s/epoch - 56ms/step
# Epoch 26/50
#
# Epoch 26: val_loss improved from 1.35355 to 1.32233, saving model to model.h5
# 61/61 - 3s - loss: 1.3777 - accuracy: 0.5114 - val_loss: 1.3223 - val_accuracy: 0.5603 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 1.32233
# 61/61 - 2s - loss: 1.3575 - accuracy: 0.5216 - val_loss: 1.3654 - val_accuracy: 0.5257 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 1.32233
# 61/61 - 2s - loss: 1.3458 - accuracy: 0.5285 - val_loss: 1.3369 - val_accuracy: 0.5305 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 29/50
#
# Epoch 29: val_loss improved from 1.32233 to 1.31532, saving model to model.h5
# 61/61 - 3s - loss: 1.3444 - accuracy: 0.5243 - val_loss: 1.3153 - val_accuracy: 0.5317 - lr: 0.0010 - 3s/epoch - 52ms/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 1.31532
# 61/61 - 3s - loss: 1.3320 - accuracy: 0.5343 - val_loss: 1.3641 - val_accuracy: 0.5400 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 1.31532
# 61/61 - 3s - loss: 1.3337 - accuracy: 0.5279 - val_loss: 1.3218 - val_accuracy: 0.5352 - lr: 0.0010 - 3s/epoch - 41ms/step
# Epoch 32/50
#
# Epoch 32: val_loss improved from 1.31532 to 1.30918, saving model to model.h5
# 61/61 - 3s - loss: 1.3162 - accuracy: 0.5371 - val_loss: 1.3092 - val_accuracy: 0.5448 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 1.30918
# 61/61 - 2s - loss: 1.3065 - accuracy: 0.5374 - val_loss: 1.3203 - val_accuracy: 0.5317 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 1.30918
# 61/61 - 2s - loss: 1.3049 - accuracy: 0.5429 - val_loss: 1.3148 - val_accuracy: 0.5221 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 1.30918
# 61/61 - 2s - loss: 1.3000 - accuracy: 0.5477 - val_loss: 1.3516 - val_accuracy: 0.5161 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 1.30918
# 61/61 - 2s - loss: 1.2796 - accuracy: 0.5463 - val_loss: 1.3208 - val_accuracy: 0.5496 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 1.30918
# 61/61 - 2s - loss: 1.2738 - accuracy: 0.5474 - val_loss: 1.3173 - val_accuracy: 0.5114 - lr: 0.0010 - 2s/epoch - 40ms/step
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 1.30918
# 61/61 - 2s - loss: 1.2765 - accuracy: 0.5501 - val_loss: 1.3149 - val_accuracy: 0.5472 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 1.30918
# 61/61 - 2s - loss: 1.2549 - accuracy: 0.5606 - val_loss: 1.3167 - val_accuracy: 0.5448 - lr: 0.0010 - 2s/epoch - 37ms/step
# Epoch 40/50
#
# Epoch 40: val_loss improved from 1.30918 to 1.30289, saving model to model.h5
# 61/61 - 3s - loss: 1.2361 - accuracy: 0.5671 - val_loss: 1.3029 - val_accuracy: 0.5317 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 41/50
#
# Epoch 41: val_loss improved from 1.30289 to 1.29480, saving model to model.h5
# 61/61 - 3s - loss: 1.2614 - accuracy: 0.5577 - val_loss: 1.2948 - val_accuracy: 0.5759 - lr: 0.0010 - 3s/epoch - 47ms/step
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 1.29480
# 61/61 - 2s - loss: 1.2483 - accuracy: 0.5595 - val_loss: 1.3263 - val_accuracy: 0.5448 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 1.29480
# 61/61 - 3s - loss: 1.2602 - accuracy: 0.5593 - val_loss: 1.3113 - val_accuracy: 0.5329 - lr: 0.0010 - 3s/epoch - 42ms/step
# Epoch 44/50
#
# Epoch 44: val_loss improved from 1.29480 to 1.29065, saving model to model.h5
# 61/61 - 3s - loss: 1.2347 - accuracy: 0.5630 - val_loss: 1.2907 - val_accuracy: 0.5484 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 1.29065
# 61/61 - 2s - loss: 1.2454 - accuracy: 0.5610 - val_loss: 1.3357 - val_accuracy: 0.5436 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 1.29065
# 61/61 - 2s - loss: 1.2122 - accuracy: 0.5774 - val_loss: 1.3170 - val_accuracy: 0.5496 - lr: 0.0010 - 2s/epoch - 36ms/step
# Epoch 47/50
#
# Epoch 47: val_loss improved from 1.29065 to 1.27080, saving model to model.h5
# 61/61 - 3s - loss: 1.2176 - accuracy: 0.5765 - val_loss: 1.2708 - val_accuracy: 0.5532 - lr: 0.0010 - 3s/epoch - 49ms/step
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 1.27080
# 61/61 - 2s - loss: 1.2048 - accuracy: 0.5792 - val_loss: 1.3213 - val_accuracy: 0.5532 - lr: 0.0010 - 2s/epoch - 41ms/step
# Epoch 49/50
#
# Epoch 49: val_loss improved from 1.27080 to 1.26778, saving model to model.h5
# 61/61 - 3s - loss: 1.2137 - accuracy: 0.5713 - val_loss: 1.2678 - val_accuracy: 0.5771 - lr: 0.0010 - 3s/epoch - 56ms/step
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 1.26778
# 61/61 - 2s - loss: 1.1963 - accuracy: 0.5763 - val_loss: 1.2981 - val_accuracy: 0.5364 - lr: 0.0010 - 2s/epoch - 35ms/step
# 27/27 [==============================] - 1s 20ms/step - loss: 1.2981 - accuracy: 0.5364
# Validation accuracy: 0.5364396572113037
# 27/27 [==============================] - 2s 22ms/step
# 100%|██████████| 10/10 [27:03<00:00, 162.30s/it]
# List of scores[0.5922107696533203, 0.5213963985443115, 0.4648648500442505, 0.43232324719429016, 0.5170940160751343, 0.4896719455718994, 0.4868735074996948, 0.4975185990333557, 0.6176470518112183, 0.5364396572113037]
# Average accuracy: 0.5156040042638779 with standard deviation 0.05299662038310091
# Trained only the last -8 layers
